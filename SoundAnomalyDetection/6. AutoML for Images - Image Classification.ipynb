# %% [markdown]
# # Anomaly Detection using Audio
# ## 6. AutoML for Images

# %% [markdown]
# <img src="soundanomaly.jpg">

# %% [markdown]
# <img src="https://github.com/retkowsky/AutoMLforImages/blob/main/images/AutoML%20for%20Images.png?raw=true" width=700>

# %% [markdown]
# Setup AutoML for Images:
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models
#
# Documentation:
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#model-specific-hyperparameters
#
# Supported Algorithms:
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#supported-model-algorithms

# %% [markdown]
# ## 1. Informations

# %%
#!pip install pydub

# %%
import numpy as np
import json
import os
import urllib
from zipfile import ZipFile
import pandas as pd

# %%
import sys
print("Python version =", sys.version)
# Out:
# Python version = 3.6.6 |Anaconda, Inc.| (default, Oct  9 2018, 12:34:16)
# [GCC 7.3.0]

# %%
import datetime
now = datetime.datetime.now()
print("Today =", now)
# Out:
# Today = 2022-03-21 11:06:26.896209

# %%
# Your local platform
import platform,socket,re,uuid,json,psutil,logging

def getSystemInfo():
    try:
        info={}
        info['Platform']=platform.system()
        info['Platform-release']=platform.release()
        info['Platform-version']=platform.version()
        info['Architecture']=platform.machine()
        info['Hostname']=socket.gethostname()
        info['IP-address']=socket.gethostbyname(socket.gethostname())
        info['MAC-address']=':'.join(re.findall('..', '%012x' % uuid.getnode()))
        info['Processor']=platform.processor()
        info['RAM']=str(round(psutil.virtual_memory().total / (1024.0 **3)))+" Go"
        return json.dumps(info)
    except Exception as e:
        logging.exception(e)

json.loads(getSystemInfo())
# Out:
# {'Platform': 'Linux',
#  'Platform-release': '5.4.0-1056-azure',
#  'Platform-version': '#58~18.04.1-Ubuntu SMP Wed Jul 28 23:14:18 UTC 2021',
#  'Architecture': 'x86_64',
#  'Hostname': 'seretkow9',
#  'IP-address': '127.0.0.1',
#  'MAC-address': '00:0d:3a:bb:38:dc',
#  'Processor': 'x86_64',
#  'RAM': '14 Go'}

# %%
import azureml.core
print("You are using Azure ML version", azureml.core.VERSION)
# Out:
# You are using Azure ML version 1.35.0

# %% [markdown]
# ## 2. Workspace setup
# In order to train and deploy models in Azure ML, you will first need to set up a workspace.
#
# An [Azure ML Workspace](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#workspace) is an Azure resource that organizes and coordinates the actions of many other Azure resources to assist in executing and sharing machine learning workflows. In particular, an Azure ML Workspace coordinates storage, databases, and compute resources providing added functionality for machine learning experimentation, deployment, inference, and the monitoring of deployed models.
#
# > Create an Azure ML Workspace within your Azure subscription, or load an existing workspace.

# %%
subscription_id = os.environ.get("SUBSCRIPTION_ID", "tobereplaced")
resource_group = os.environ.get("RESOURCE_GROUP", "azuremlvision-rg")
workspace_name = os.environ.get("WORKSPACE_NAME", "azuremlvision")

# %%
from azureml.core import Workspace
try:
    ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
    ws.write_config()
    print("OK")
except:
    print("Error: Workspace not found")
# Out:
# OK

# %%
from azureml.core import Workspace
ws = Workspace.from_config()

# %%
ws.name, ws.resource_group
# Out:
# ('azuremlvision', 'azuremlvision-rg')

# %% [markdown]
# ## 3. Azure ML GPU Compute target setup
# **You will need to provide a [Compute Target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) that will be used for your AutoML model training.** <br><br>
# **AutoML models for image tasks require GPU SKUs and support NC and ND families.** We recommend using the NCsv3-series (with v100 GPUs) for faster training. Using a compute target with a multi-GPU VM SKU will leverage the multiple GPUs to speed up training. Additionally, setting up a compute target with multiple nodes will allow for faster model training by leveraging parallelism, when tuning hyperparameters for your model.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

cluster_name = "AutoMLGPUsound"

try:
    compute_target = ws.compute_targets[cluster_name]
    print('Found existing compute target.')
except KeyError:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_NC6', #GPU cluster
                                                           idle_seconds_before_scaledown=1800, #Time out
                                                           min_nodes=0, 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

# Can poll for a minimum number of nodes and for a specific timeout.
# If no min_node_count is provided, it will use the scale settings for the cluster.
compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Creating a new compute target...
# InProgress..
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
# Compute status
compute_target.provisioning_state
# Out:
# 'Succeeded'

# %%
# Compute cluster information
compute_target.get_status().serialize()
# Out:
# {'currentNodeCount': 0,
#  'targetNodeCount': 0,
#  'nodeStateCounts': {'preparingNodeCount': 0,
#   'runningNodeCount': 0,
#   'idleNodeCount': 0,
#   'unusableNodeCount': 0,
#   'leavingNodeCount': 0,
#   'preemptedNodeCount': 0},
#  'allocationState': 'Resizing',
#  'allocationStateTransitionTime': '2022-03-21T11:07:39.386000+00:00',
#  'errors': None,
#  'creationTime': '2022-03-21T11:07:38.387015+00:00',
#  'modifiedTime': '2022-03-21T11:07:45.592711+00:00',
#  'provisioningState': 'Succeeded',
#  'provisioningStateTransitionTime': None,
#  'scaleSettings': {'minNodeCount': 0,
#   'maxNodeCount': 4,
#   'nodeIdleTimeBeforeScaleDown': 'PT1800S'},
#  'vmPriority': 'Dedicated',
#  'vmSize': 'STANDARD_NC6'}

# %%
# Compute VM size
compute_target.vm_size
# Out:
# 'STANDARD_NC6'

# %% [markdown]
# ## 4. Experiment Setup
# Create an [Experiment](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#experiment) in your workspace to track your model training runs

# %%
from azureml.core import Experiment

experiment_name = 'AutoMLImages-SoundAnomaly' #Name of your experimentation
experiment = Experiment(ws, name=experiment_name)

# %%
experiment
# Out:
# Experiment(Name: AutoMLImages-SoundAnomaly,
# Workspace: azuremlvision)

# %% [markdown]
# ## 5. Dataset with input Training Data
# In order to generate models for computer vision, you will need to bring in labeled image data as input for model training in the form of an AzureML Labeled Dataset. You can either use a Labeled Dataset that you have exported from a Data Labeling project, or create a new Labeled Dataset with your labeled training data

# %%
# %cd spectogramsmachine
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/seretkow9/code/Users/seretkow/Sound/MachineSoundAnomaly/spectogramsmachine

# %%
# We have some images for the tags in directories we want to detect
print(os.listdir('.'))
# Out:
# ['KO', 'OK']

# %%
for root, _, files in os.walk('.'):
    print("Dir:", root, " = ", len(files), "images files.")
# Out:
# Dir: .  =  0 images files.
# Dir: ./KO  =  61 images files.
# Dir: ./OK  =  61 images files.

# %%
from IPython.display import Image
sample_image = 'KO/machine_KO_1.jpg'
Image(filename=sample_image)

# %% [markdown]
# ### Convert the downloaded data to JSONL

# %%
# %cd ..
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/seretkow9/code/Users/seretkow/Sound/MachineSoundAnomaly

# %%
src = "spectogramsmachine/"

train_validation_ratio = 5

# Retrieving default datastore that got automatically created when we setup a workspace
workspaceblobstore = ws.get_default_datastore().name

# Path to the training and validation files
train_annotations_file = os.path.join(src, "train_annotations.jsonl")
validation_annotations_file = os.path.join(src, "validation_annotations.jsonl")

# sample json line dictionary
json_line_sample = \
    {
        "image_url": "AmlDatastore://" + workspaceblobstore + "/"
                     + os.path.basename(os.path.dirname(src)),
        "label": "",
        "label_confidence": 1.0
    }

index = 0
# Scan each sub directary and generate jsonl line
with open(train_annotations_file, 'w') as train_f:
    with open(validation_annotations_file, 'w') as validation_f:
        for className in os.listdir(src):
            subDir = src + className
            if not os.path.isdir(subDir):
                continue
            # Scan each sub directary
            print("Parsing " + subDir)
            for image in os.listdir(subDir):
                json_line = dict(json_line_sample)
                json_line["image_url"] += f"/{className}/{image}"
                json_line["label"] = className

                if index % train_validation_ratio == 0:
                    # validation annotation
                    validation_f.write(json.dumps(json_line) + "\n")
                else:
                    # train annotation
                    train_f.write(json.dumps(json_line) + "\n")
                index += 1
# Out:
# Parsing spectogramsmachine/KO
# Parsing spectogramsmachine/OK

# %% [markdown]
# ### Upload the JSONL file and images to Datastore
# In order to use the data for training in Azure ML, we upload it to our Azure ML Workspace via a [Datastore](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores). The datastore provides a mechanism for you to upload/download data, and interact with it from your remote compute targets. It is an abstraction over Azure Storage.

# %%
# Retrieving default datastore that got automatically created when we setup a workspace
ds = ws.get_default_datastore()
ds.upload(src_dir='./spectogramsmachine/', target_path='spectogramsmachine')
# Out:
# Uploading an estimated of 124 files
# Uploading ./spectogramsmachine/train_annotations.jsonl
# Uploaded ./spectogramsmachine/train_annotations.jsonl, 1 files out of an estimated total of 124
# Uploading ./spectogramsmachine/validation_annotations.jsonl
# Uploaded ./spectogramsmachine/validation_annotations.jsonl, 2 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_1.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_1.jpg, 3 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_10.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_10.jpg, 4 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_11.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_11.jpg, 5 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_12.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_12.jpg, 6 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_13.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_13.jpg, 7 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_14.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_14.jpg, 8 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_15.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_15.jpg, 9 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_16.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_16.jpg, 10 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_17.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_17.jpg, 11 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_18.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_18.jpg, 12 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_19.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_19.jpg, 13 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_2.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_2.jpg, 14 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_20.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_20.jpg, 15 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_21.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_21.jpg, 16 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_22.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_22.jpg, 17 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_23.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_23.jpg, 18 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_24.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_24.jpg, 19 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_25.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_25.jpg, 20 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_26.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_26.jpg, 21 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_27.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_27.jpg, 22 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_28.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_28.jpg, 23 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_29.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_29.jpg, 24 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_3.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_3.jpg, 25 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_30.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_30.jpg, 26 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_31.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_31.jpg, 27 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_32.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_32.jpg, 28 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_33.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_33.jpg, 29 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_34.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_34.jpg, 30 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_35.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_35.jpg, 31 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_36.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_36.jpg, 32 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_37.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_37.jpg, 33 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_38.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_38.jpg, 34 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_39.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_39.jpg, 35 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_4.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_4.jpg, 36 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_40.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_40.jpg, 37 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_41.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_41.jpg, 38 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_42.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_42.jpg, 39 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_43.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_43.jpg, 40 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_44.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_44.jpg, 41 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_45.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_45.jpg, 42 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_46.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_46.jpg, 43 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_47.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_47.jpg, 44 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_48.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_48.jpg, 45 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_49.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_49.jpg, 46 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_5.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_5.jpg, 47 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_50.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_50.jpg, 48 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_51.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_51.jpg, 49 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_52.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_52.jpg, 50 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_53.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_53.jpg, 51 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_54.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_54.jpg, 52 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_55.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_55.jpg, 53 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_56.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_56.jpg, 54 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_57.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_57.jpg, 55 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_58.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_58.jpg, 56 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_59.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_59.jpg, 57 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_6.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_6.jpg, 58 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_60.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_60.jpg, 59 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_61.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_61.jpg, 60 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_7.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_7.jpg, 61 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_8.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_8.jpg, 62 files out of an estimated total of 124
# Uploading ./spectogramsmachine/KO/machine_KO_9.jpg
# Uploaded ./spectogramsmachine/KO/machine_KO_9.jpg, 63 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_1.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_1.jpg, 64 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_10.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_10.jpg, 65 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_11.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_11.jpg, 66 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_12.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_12.jpg, 67 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_13.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_13.jpg, 68 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_14.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_14.jpg, 69 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_15.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_15.jpg, 70 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_16.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_16.jpg, 71 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_17.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_17.jpg, 72 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_18.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_18.jpg, 73 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_19.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_19.jpg, 74 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_2.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_2.jpg, 75 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_20.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_20.jpg, 76 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_21.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_21.jpg, 77 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_22.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_22.jpg, 78 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_23.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_23.jpg, 79 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_24.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_24.jpg, 80 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_25.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_25.jpg, 81 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_26.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_26.jpg, 82 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_27.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_27.jpg, 83 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_28.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_28.jpg, 84 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_29.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_29.jpg, 85 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_3.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_3.jpg, 86 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_30.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_30.jpg, 87 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_31.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_31.jpg, 88 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_32.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_32.jpg, 89 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_33.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_33.jpg, 90 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_34.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_34.jpg, 91 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_35.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_35.jpg, 92 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_36.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_36.jpg, 93 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_37.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_37.jpg, 94 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_38.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_38.jpg, 95 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_39.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_39.jpg, 96 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_4.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_4.jpg, 97 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_40.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_40.jpg, 98 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_42.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_42.jpg, 99 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_43.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_43.jpg, 100 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_45.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_45.jpg, 101 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_47.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_47.jpg, 102 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_48.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_48.jpg, 103 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_41.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_41.jpg, 104 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_44.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_44.jpg, 105 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_46.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_46.jpg, 106 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_49.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_49.jpg, 107 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_5.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_5.jpg, 108 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_50.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_50.jpg, 109 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_51.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_51.jpg, 110 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_52.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_52.jpg, 111 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_53.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_53.jpg, 112 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_54.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_54.jpg, 113 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_55.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_55.jpg, 114 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_56.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_56.jpg, 115 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_57.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_57.jpg, 116 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_58.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_58.jpg, 117 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_59.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_59.jpg, 118 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_6.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_6.jpg, 119 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_60.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_60.jpg, 120 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_61.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_61.jpg, 121 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_7.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_7.jpg, 122 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_8.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_8.jpg, 123 files out of an estimated total of 124
# Uploading ./spectogramsmachine/OK/machine_OK_9.jpg
# Uploaded ./spectogramsmachine/OK/machine_OK_9.jpg, 124 files out of an estimated total of 124
# Uploaded 124 files
# $AZUREML_DATAREFERENCE_2dd7a5d7cbaa475c9182250103e8b60d

# %%
ds
# Out:
# {
#   "name": "workspaceblobstore",
#   "container_name": "azureml-blobstore-c3c87d4d-5b7e-436b-8a1a-5765a35e9878",
#   "account_name": "azuremlvision8724517013",
#   "protocol": "https",
#   "endpoint": "core.windows.net"
# }

# %% [markdown]
# Finally, we need to create an Azure ML [Dataset](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores) from the data we uploaded to the Datastore. We create one dataset for training and one for validation.

# %%
from azureml.contrib.dataset.labeled_dataset import _LabeledDatasetFactory, LabeledDatasetTask
from azureml.core import Dataset

training_dataset_name = 'machinesoundTrainingDataset'
if training_dataset_name in ws.datasets:
    training_dataset = ws.datasets.get(training_dataset_name)
    print('Found the training dataset', training_dataset_name)
else:
    # create training dataset
    training_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('spectogramsmachine/train_annotations.jsonl'))
    training_dataset = training_dataset.register(workspace=ws, name=training_dataset_name)
    
# create validation dataset
validation_dataset_name = "machinesoundValidationDataset"
if validation_dataset_name in ws.datasets:
    validation_dataset = ws.datasets.get(validation_dataset_name)
    print('Found the validation dataset', validation_dataset_name)
else:
    validation_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('spectogramsmachine/validation_annotations.jsonl'))
    validation_dataset = validation_dataset.register(workspace=ws, name=validation_dataset_name)

print()
print("Training dataset name:" + training_dataset.name)
print("Validation dataset name:" + validation_dataset.name)
# Out:
# Training dataset name:machinesoundTrainingDataset
# Validation dataset name:machinesoundValidationDataset

# %% [markdown]
# Validation dataset is optional. If no validation dataset is specified, by default 20% of your training data will be used for validation. You can control the percentage using the `split_ratio` argument - please refer to the documentation for more details.
#
# This is what the training dataset looks like

# %%
images=training_dataset.to_pandas_dataframe()

# %%
images.head()
# Out:
#                                            image_url label  label_confidence
# 0  StreamInfo(AmlDatastore://spectogramsmachine/K...    KO               1.0
# 1  StreamInfo(AmlDatastore://spectogramsmachine/K...    KO               1.0
# 2  StreamInfo(AmlDatastore://spectogramsmachine/K...    KO               1.0
# 3  StreamInfo(AmlDatastore://spectogramsmachine/K...    KO               1.0
# 4  StreamInfo(AmlDatastore://spectogramsmachine/K...    KO               1.0

# %%
images.shape
# Out:
# (97, 3)

# %%
images['label'].value_counts()
# Out:
# OK    49
# KO    48
# Name: label, dtype: int64

# %%
# Percentage values
images['label'].value_counts(normalize=True)
# Out:
# OK    0.505155
# KO    0.494845
# Name: label, dtype: float64

# %%
from IPython.display import Image
# %matplotlib inline
import matplotlib.pyplot as plt
images['label'].value_counts(sort=True).plot.bar()

# %% [markdown]
# ## 6. Configuring your AutoML run for image tasks
# AutoML allows you to easily train models for Image Classification, Object Detection & Instance Segmentation on your image data. You can control the model algorithm to be used, specify hyperparameter values for your model as well as perform a sweep across the hyperparameter space to generate an optimal model. Parameters for configuring your AutoML runs for image related tasks are specified using the 'AutoMLImageConfig' - please refer to the [documentation](https://github.com/swatig007/automlForImages#readme) for the details on the parameters that can be used and their values.

# %% [markdown]
# When using AutoML for image tasks, you need to specify the model algorithms using the `model_name` parameter. You can either specify a single model or choose to sweep over multiple ones.<br><br>
#
# ### Using default hyperparameter values for the specified algorithm
#
# Before doing a large sweep to search for the optimal models and hyperparameters, we recommend trying the default values to get a first baseline. Next, you can explore multiple hyperparameters for the same model before sweeping over multiple models and their parameters. This is for employing a more iterative approach, because with multiple models and multiple hyperparameters for each (as we showcase in the next section), the search space grows exponentially and you need more iterations to find optimal configurations.

# %% [markdown]
# Supported Algorithms
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#supported-model-algorithms

# %%
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import RandomParameterSampling
from azureml.train.hyperdrive import GridParameterSampling
from azureml.train.hyperdrive import choice
from azureml.automl.core.shared.constants import ImageTask

# %%
# AutoML Configuration
image_config = AutoMLImageConfig(task=ImageTask.IMAGE_CLASSIFICATION, # AutoML Vision task
                                 compute_target=compute_target, # Compute target
                                 training_data=training_dataset, # Training dataset
                                 validation_data=validation_dataset, # Validation dataset
                                 iterations = 1,
                                 hyperparameter_sampling=GridParameterSampling({'model_name': 
                                                                                choice('vitb16r224')})) # CV Model

# %% [markdown]
# ## 7. Submitting an AutoML run for Computer Vision tasks
# Once you've created the config settings for your run, **you can submit an AutoML run** using the config in order to train a vision model using your training dataset.

# %%
automl_image_run = experiment.submit(image_config)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>AutoMLImages-SoundAnomaly</td><td>AutoML_75d3f18c-475a-419f-bbbb-9672e8080892</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_75d3f18c-475a-419f-bbbb-9672e8080892?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlvision-rg/workspaces/azuremlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True) # Wait until automl run is finished
# Out:
# {'runId': 'AutoML_75d3f18c-475a-419f-bbbb-9672e8080892',
#  'target': 'AutoMLGPUsound',
#  'status': 'Completed',
#  'startTimeUtc': '2022-03-21T11:09:25.721238Z',
#  'endTimeUtc': '2022-03-21T11:23:11.00878Z',
#  'services': {},
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'AutoMLGPUsound',
#   'AMLSettingsJsonString': '{"path":null,"name":"AutoMLImages-SoundAnomaly","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"azuremlvision-rg","workspace_name":"azuremlvision","region":"westeurope","compute_target":"AutoMLGPUsound","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":true,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"accuracy","task_type":"image-classification","positive_label":null,"data_script":null,"test_size":0.0,"test_include_predictions_only":false,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"enable_categorical_indicators":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":true,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"0ae3e4f2-9723-4bce-b7e7-aa2c3ad194cd","hyperdrive_config":{"max_total_jobs":1,"max_concurrent_jobs":1,"generator_config":{"name":"GRID","parameter_space":"{\\"model_name\\": [\\"choice\\", [[\\"vitb16r224\\"]]]}","properties":null},"policy_config":null},"validation_dataset_id":"602692e2-7074-4f10-b4d6-c05286dd5caf","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"0ae3e4f2-9723-4bce-b7e7-aa2c3ad194cd\\"}, \\"validation_data\\": {\\"datasetId\\": \\"602692e2-7074-4f10-b4d6-c05286dd5caf\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'AutoMLImageSDK',
#   'display_task_type': 'image-classification',
#   'dependencies_versions': '{"azureml-widgets": "1.35.0", "azureml-train-restclients-hyperdrive": "1.35.0", "azureml-train-core": "1.35.0", "azureml-train-automl-runtime": "1.35.1", "azureml-train-automl-client": "1.35.0", "azureml-telemetry": "1.35.0", "azureml-pipeline-steps": "1.35.0", "azureml-pipeline-core": "1.35.0", "azureml-mlflow": "1.35.0", "azureml-interpret": "1.35.0", "azureml-inference-server-http": "0.3.2", "azureml-defaults": "1.35.0", "azureml-dataset-runtime": "1.35.0", "azureml-dataprep": "2.23.2", "azureml-dataprep-rslex": "1.21.2", "azureml-dataprep-native": "38.0.0", "azureml-core": "1.35.0.post1", "azureml-contrib-dataset": "1.35.0", "azureml-contrib-automl-pipeline-steps": "1.35.1", "azureml-automl-runtime": "1.35.1", "azureml-automl-core": "1.35.1"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'AutoMLImageSDK',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/azuremlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/azuremlvision/experimentids/e13c9d5f-eb83-424e-90dc-eae2ab55279c/cancel/AutoML_75d3f18c-475a-419f-bbbb-9672e8080892',
#   'ClientSdkVersion': '1.39.1',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': '0ae3e4f2-9723-4bce-b7e7-aa2c3ad194cd'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': '602692e2-7074-4f10-b4d6-c05286dd5caf'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %%
automl_image_run.id
# Out:
# 'AutoML_75d3f18c-475a-419f-bbbb-9672e8080892'

# %%
experiment
# Out:
# Experiment(Name: AutoMLImages-SoundAnomaly,
# Workspace: azuremlvision)

# %%
from azureml.widgets import RunDetails
RunDetails(automl_image_run).show()
# Out:
# _AutoMLWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', 's…

# %%
# List of all the AutoML for Images metrics values
automlvisionmetrics = automl_image_run.get_metrics()
automlvisionmetrics
# Out:
# {'precision_score_micro': [0.52,
#   0.76,
#   0.52,
#   0.8,
#   0.76,
#   0.8,
#   0.72,
#   0.72,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84],
#  'precision_score_macro': [0.26,
#   0.76623,
#   0.26,
#   0.81667,
#   0.76623,
#   0.80128,
#   0.72078,
#   0.72078,
#   0.8474,
#   0.875,
#   0.875,
#   0.8474,
#   0.8474,
#   0.8474,
#   0.8474],
#  'classification_report': {'class_name': ['KO',
#    'OK',
#    'micro avg',
#    'macro avg',
#    'weighted avg'],
#   'precision': [0.90909, 0.78571, 0.84, 0.8474, 0.84987],
#   'recall': [0.76923, 0.91667, 0.84, 0.84295, 0.84],
#   'f1-score': [0.83333, 0.84615, 0.84, 0.83974, 0.83949],
#   'support': [13.0, 12.0, 25.0, 25.0, 25.0],
#   'auc': [0.88462, 0.88462, 0.904, 0.88462, 0.88462],
#   'average_precision': [0.91993, 0.87416, 0.91386, 0.89704, 0.89796]},
#  'f1_score_micro': [0.52,
#   0.76,
#   0.52,
#   0.8,
#   0.76,
#   0.8,
#   0.72,
#   0.72,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84],
#  'average_precision_score_binary': [0.44243,
#   0.7803,
#   0.81512,
#   0.83633,
#   0.83099,
#   0.81869,
#   0.75897,
#   0.77614,
#   0.76503,
#   0.85134,
#   0.90458,
#   0.89416,
#   0.87416,
#   0.87416,
#   0.87416],
#  'average_precision_score_macro': [0.53659,
#   0.82387,
#   0.85296,
#   0.86845,
#   0.86703,
#   0.86271,
#   0.82986,
#   0.8413,
#   0.83465,
#   0.88309,
#   0.91654,
#   0.90987,
#   0.89704,
#   0.89704,
#   0.89704],
#  'average_precision_score_weighted': [0.54035,
#   0.82561,
#   0.85448,
#   0.86973,
#   0.86847,
#   0.86447,
#   0.83269,
#   0.84391,
#   0.83743,
#   0.88436,
#   0.91702,
#   0.9105,
#   0.89796,
#   0.89796,
#   0.89796],
#  'AUC_weighted': [0.44872,
#   0.8141,
#   0.83333,
#   0.85256,
#   0.85256,
#   0.85256,
#   0.83333,
#   0.84615,
#   0.83974,
#   0.87179,
#   0.90385,
#   0.89744,
#   0.88462,
#   0.88462,
#   0.88462],
#  'recall_score_macro': [0.5,
#   0.76282,
#   0.5,
#   0.80449,
#   0.76282,
#   0.80128,
#   0.71795,
#   0.71795,
#   0.84295,
#   0.84615,
#   0.84615,
#   0.84295,
#   0.84295,
#   0.84295,
#   0.84295],
#  'precision_score_weighted': [0.2704,
#   0.76831,
#   0.2704,
#   0.82,
#   0.76831,
#   0.80256,
#   0.72052,
#   0.72052,
#   0.84987,
#   0.88,
#   0.88,
#   0.84987,
#   0.84987,
#   0.84987,
#   0.84987],
#  'log_loss': [0.70292,
#   0.60497,
#   1.12885,
#   0.47125,
#   0.47406,
#   0.46516,
#   0.49463,
#   0.47502,
#   0.39511,
#   0.41144,
#   0.43958,
#   0.41697,
#   0.4191,
#   0.42157,
#   0.42157],
#  'average_precision_score_micro': [0.56896,
#   0.77385,
#   0.74014,
#   0.90112,
#   0.89679,
#   0.88914,
#   0.83933,
#   0.84431,
#   0.89256,
#   0.91791,
#   0.93378,
#   0.93058,
#   0.91657,
#   0.91386,
#   0.91386],
#  'recall_score_weighted': [0.52,
#   0.76,
#   0.52,
#   0.8,
#   0.76,
#   0.8,
#   0.72,
#   0.72,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84],
#  'AUC_binary': [0.44872,
#   0.8141,
#   0.83333,
#   0.85256,
#   0.85256,
#   0.85256,
#   0.83333,
#   0.84615,
#   0.83974,
#   0.87179,
#   0.90385,
#   0.89744,
#   0.88462,
#   0.88462,
#   0.88462],
#  'accuracy': [0.52,
#   0.76,
#   0.52,
#   0.8,
#   0.76,
#   0.8,
#   0.72,
#   0.72,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84],
#  'f1_score_weighted': [0.35579,
#   0.75923,
#   0.35579,
#   0.79807,
#   0.75923,
#   0.8,
#   0.7191,
#   0.7191,
#   0.83949,
#   0.83688,
#   0.83688,
#   0.83949,
#   0.83949,
#   0.83949,
#   0.83949],
#  'f1_score_macro': [0.34211,
#   0.75962,
#   0.34211,
#   0.79871,
#   0.75962,
#   0.8,
#   0.7182,
#   0.7182,
#   0.83974,
#   0.83766,
#   0.83766,
#   0.83974,
#   0.83974,
#   0.83974,
#   0.83974],
#  'precision_score_binary': [0.0,
#   0.71429,
#   0.0,
#   0.73333,
#   0.71429,
#   0.76923,
#   0.72727,
#   0.72727,
#   0.78571,
#   0.75,
#   0.75,
#   0.78571,
#   0.78571,
#   0.78571,
#   0.78571],
#  'log_loss_train': [0.72933,
#   0.74087,
#   0.60578,
#   0.77207,
#   0.49904,
#   0.46534,
#   0.41794,
#   0.4498,
#   0.40845,
#   0.3933,
#   0.33365,
#   0.47501,
#   0.46905,
#   0.35471],
#  'AUC_micro': [0.4944,
#   0.7856,
#   0.6864,
#   0.8896,
#   0.8848,
#   0.8768,
#   0.8224,
#   0.8288,
#   0.8848,
#   0.9104,
#   0.9264,
#   0.9232,
#   0.9072,
#   0.904,
#   0.904],
#  'recall_score_micro': [0.52,
#   0.76,
#   0.52,
#   0.8,
#   0.76,
#   0.8,
#   0.72,
#   0.72,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84,
#   0.84],
#  'AUC_macro': [0.44872,
#   0.8141,
#   0.83333,
#   0.85256,
#   0.85256,
#   0.85256,
#   0.83333,
#   0.84615,
#   0.83974,
#   0.87179,
#   0.90385,
#   0.89744,
#   0.88462,
#   0.88462,
#   0.88462],
#  'recall_score_binary': [0.0,
#   0.83333,
#   0.0,
#   0.91667,
#   0.83333,
#   0.83333,
#   0.66667,
#   0.66667,
#   0.91667,
#   1.0,
#   1.0,
#   0.91667,
#   0.91667,
#   0.91667,
#   0.91667],
#  'f1_score_binary': [0.0,
#   0.76923,
#   0.0,
#   0.81481,
#   0.76923,
#   0.8,
#   0.69565,
#   0.69565,
#   0.84615,
#   0.85714,
#   0.85714,
#   0.84615,
#   0.84615,
#   0.84615,
#   0.84615],
#  'accuracy_train': [0.49485,
#   0.48454,
#   0.70103,
#   0.58763,
#   0.7732,
#   0.78351,
#   0.81443,
#   0.79381,
#   0.81443,
#   0.81443,
#   0.85567,
#   0.7732,
#   0.83505,
#   0.86598]}

# %%
best_child_run=automl_image_run.get_best_child()
best_child_run.download_file("confusion_matrix", output_file_path = "confusion_matrix_1.json")

with open('confusion_matrix_1.json') as f:
    cm = json.load(f)

print("Confusion Matrix:")
print(cm['data']['class_labels'])
print(cm['data']['matrix'][0])
print(cm['data']['matrix'][1])

total_cm = cm['data']['matrix'][0][0]+cm['data']['matrix'][0][1] + cm['data']['matrix'][1][0]+cm['data']['matrix'][1][1]
acc = (cm['data']['matrix'][0][0]+cm['data']['matrix'][1][1]) / total_cm
err = 1 - acc
print("\nAccuracy =", round(acc, 5))
print("Error =", round(err, 5))
# Out:
# Confusion Matrix:
# ['KO', 'OK']
# [10, 3]
# [1, 11]
#
# Accuracy = 0.84
# Error = 0.16

# %%
# Let's plot the accuracy metric for the CV model, save the graph to a jpg file and log it to the Azure ML experiment
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15,8))
plt.plot(automlvisionmetrics['accuracy'], 'b-', lw=2, alpha=.6)
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title('Images Classification model - vitb16r224 accuracy', fontsize=15)
plt.grid(color='#DDDDDD', linewidth = 0.8)
plt.xticks(np.arange(0, 15, 1))
plt.savefig('automl1_accuracy.png')
automl_image_run.log_image(name='automl1_vitb16r224.png', plot=plt) # Logging the graph into the Azure ML experiment

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 8))
plt.plot(automlvisionmetrics['log_loss'], 'r-', lw = 2, alpha = .6)
plt.xlabel('Iterations', fontsize = 12)
plt.ylabel('Log Loss', fontsize = 12)
plt.title('Images Classification model - vitb16r224 Log Loss', fontsize = 15)
plt.grid( color='#DDDDDD', linewidth = 0.8)
plt.xticks(np.arange(0, 15, 1))
plt.savefig('automl1_logloss.png')
plt.show()

# %%
# You can view the jpg file in the experiment
experiment
# Out:
# Experiment(Name: AutoMLImages-SoundAnomaly,
# Workspace: azuremlvision)

# %% [markdown]
# ## Let's improve using additionals models & hyperparameter tuning

# %% [markdown]
# ### Hyperparameter sweeping for your AutoML models for computer vision tasks
#
# When using AutoML for Images, you can perform a hyperparameter sweep over a defined parameter space, to find the optimal model. In this example, we sweep over the hyperparameters for each algorithm, **choosing from a range of values for learning_rate, optimizer, lr_scheduler, etc, to generate a model with the optimal 'accuracy'.** If hyperparameter values are not specified, then default values are used for the specified algorithm.
#
# We use **Random Sampling to pick samples from this parameter space and try a total of 10 iterations** with these different samples, running 4 iterations at a time on our compute target, which has been previously set up using 4 nodes. Please note that the more parameters the space has, the more iterations you need to find optimal models.
#
# We also leverage the **Bandit early termination policy** that terminates poor performing configs (those that are not within 20% slack of the best perfroming config), thus significantly saving compute resources.

# %% [markdown]
# Supported Algorithms
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#supported-model-algorithms

# %%
from azureml.automl.core.shared.constants import ImageTask
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import BanditPolicy, RandomParameterSampling
from azureml.train.hyperdrive import choice, uniform

parameter_space = {
    "learning_rate": uniform(0.001, 0.01),
    "model": choice(
        {
            "model_name": choice("vitb16r224", "vits16r224"),
            "number_of_epochs": choice(15, 30),
        },
        {
            "model_name": choice("seresnext", "resnest50"),
            "layers_to_freeze": choice(0, 1, 2, 3),
        },
    ),
}

tuning_settings = {
    "iterations": 10,
    "max_concurrent_iterations": 4,
    "hyperparameter_sampling": RandomParameterSampling(parameter_space),
    "early_termination_policy": BanditPolicy(
        evaluation_interval=2, slack_factor=0.2, delay_evaluation=6
    ),
}

automl_image_config = AutoMLImageConfig(
    task=ImageTask.IMAGE_CLASSIFICATION,
    compute_target=compute_target,
    training_data=training_dataset,
    validation_data=validation_dataset,
    **tuning_settings,
)

# %%
automl_image_run = experiment.submit(automl_image_config)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>AutoMLImages-SoundAnomaly</td><td>AutoML_07dbecc7-90a6-4381-b82d-e1bbbb45c985</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_07dbecc7-90a6-4381-b82d-e1bbbb45c985?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlvision-rg/workspaces/azuremlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True)
# Out:
# {'runId': 'AutoML_07dbecc7-90a6-4381-b82d-e1bbbb45c985',
#  'target': 'AutoMLGPUsound',
#  'status': 'Completed',
#  'startTimeUtc': '2022-03-21T11:32:32.370587Z',
#  'endTimeUtc': '2022-03-21T11:49:24.726486Z',
#  'services': {},
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'AutoMLGPUsound',
#   'AMLSettingsJsonString': '{"path":null,"name":"AutoMLImages-SoundAnomaly","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"azuremlvision-rg","workspace_name":"azuremlvision","region":"westeurope","compute_target":"AutoMLGPUsound","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":true,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"accuracy","task_type":"image-classification","positive_label":null,"data_script":null,"test_size":0.0,"test_include_predictions_only":false,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"enable_categorical_indicators":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":true,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"0ae3e4f2-9723-4bce-b7e7-aa2c3ad194cd","hyperdrive_config":{"max_total_jobs":10,"max_concurrent_jobs":4,"generator_config":{"name":"RANDOM","parameter_space":"{\\"learning_rate\\": [\\"uniform\\", [0.001, 0.01]], \\"model\\": [\\"choice\\", [[{\\"model_name\\": [\\"choice\\", [[\\"vitb16r224\\", \\"vits16r224\\"]]], \\"number_of_epochs\\": [\\"choice\\", [[15, 30]]]}, {\\"model_name\\": [\\"choice\\", [[\\"seresnext\\", \\"resnest50\\"]]], \\"layers_to_freeze\\": [\\"choice\\", [[0, 1, 2, 3]]]}]]]}","properties":null},"policy_config":{"name":"Bandit","properties":{"evaluation_interval":2,"delay_evaluation":6,"slack_factor":0.2}}},"validation_dataset_id":"602692e2-7074-4f10-b4d6-c05286dd5caf","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"0ae3e4f2-9723-4bce-b7e7-aa2c3ad194cd\\"}, \\"validation_data\\": {\\"datasetId\\": \\"602692e2-7074-4f10-b4d6-c05286dd5caf\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'AutoMLImageSDK',
#   'display_task_type': 'image-classification',
#   'dependencies_versions': '{"azureml-widgets": "1.35.0", "azureml-train-restclients-hyperdrive": "1.35.0", "azureml-train-core": "1.35.0", "azureml-train-automl-runtime": "1.35.1", "azureml-train-automl-client": "1.35.0", "azureml-telemetry": "1.35.0", "azureml-pipeline-steps": "1.35.0", "azureml-pipeline-core": "1.35.0", "azureml-mlflow": "1.35.0", "azureml-interpret": "1.35.0", "azureml-inference-server-http": "0.3.2", "azureml-defaults": "1.35.0", "azureml-dataset-runtime": "1.35.0", "azureml-dataprep": "2.23.2", "azureml-dataprep-rslex": "1.21.2", "azureml-dataprep-native": "38.0.0", "azureml-core": "1.35.0.post1", "azureml-contrib-dataset": "1.35.0", "azureml-contrib-automl-pipeline-steps": "1.35.1", "azureml-automl-runtime": "1.35.1", "azureml-automl-core": "1.35.1"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'AutoMLImageSDK',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/azuremlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/azuremlvision/experimentids/e13c9d5f-eb83-424e-90dc-eae2ab55279c/cancel/AutoML_07dbecc7-90a6-4381-b82d-e1bbbb45c985',
#   'ClientSdkVersion': '1.39.1',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': '0ae3e4f2-9723-4bce-b7e7-aa2c3ad194cd'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': '602692e2-7074-4f10-b4d6-c05286dd5caf'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %% [markdown]
# > When doing a hyperparameter sweep, **it can be useful to visualize the different configurations that were tried using the HyperDrive UI**. <br><br>You can navigate to this UI by going to the **'Child runs' tab in the UI of the main automl_image_run** from above, which is the HyperDrive parent run. Then you can go into the 'Child runs' tab of this one.

# %%
experiment

# %% [markdown]
# ### You will see all the AutoML runs from the Child runs section.
# The **model column** will display detailled information about each model.<br>
# Example:

# %% [markdown]
# <img src="https://github.com/retkowsky/images/blob/master/automlvision.jpg?raw=true">

# %%
from azureml.widgets import RunDetails
RunDetails(automl_image_run).show()
# Out:
# _AutoMLWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', 's…

# %%
best_child_run=automl_image_run.get_best_child()
best_child_run.download_file("confusion_matrix", output_file_path = "confusion_matrix_2.json")

with open('confusion_matrix_2.json') as f:
    cm = json.load(f)

print("Confusion Matrix:")
print(cm['data']['class_labels'])
print(cm['data']['matrix'][0])
print(cm['data']['matrix'][1])

total_cm = cm['data']['matrix'][0][0]+cm['data']['matrix'][0][1] + cm['data']['matrix'][1][0]+cm['data']['matrix'][1][1]
acc = (cm['data']['matrix'][0][0]+cm['data']['matrix'][1][1]) / total_cm
err = 1 - acc
print("\nAccuracy =", round(acc, 5))
print("Error =", round(err, 5))
# Out:
# Confusion Matrix:
# ['KO', 'OK']
# [10, 3]
# [0, 12]
#
# Accuracy = 0.88
# Error = 0.12

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15,8))
plt.plot(automlvisionmetrics['accuracy'], 'b-', lw=2, alpha=.6)
plt.xlabel('iterations', fontsize=12)
plt.ylabel('accuracy', fontsize=12)
plt.title('Images Classification model - Best Model accuracy', fontsize=15)
plt.grid(color='#DDDDDD', linewidth = 0.8)
plt.xticks(np.arange(0, 15, 1))
plt.savefig('automl2_accuracy.png') # Saving image in a jpg file
automl_image_run.log_image(name='automl2_accuracy.png', plot=plt) # Logging the graph into the Azure ML experiment

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 8))
plt.plot(automlvisionmetrics['log_loss'], 'r-', lw = 2, alpha = .6)
plt.xlabel('Iterations', fontsize = 12)
plt.ylabel('Log Loss', fontsize = 12)
plt.title('Images Classification model - Best Model Log Loss', fontsize = 15)
plt.grid( color='#DDDDDD', linewidth = 0.8)
plt.xticks(np.arange(0, 15, 1))
plt.savefig('automl2_logloss.png')
plt.show()

# %% [markdown]
# > You can find all the artefacts from the output+logs section of Azure ML

# %% [markdown]
# ## 8. Register the optimal CV model from the AutoML run
# Once the run completes, we can register the model that was created from the best run (configuration that resulted in the best primary metric)

# %%
from azureml.core import Run
hyperdrive_run = Run(experiment=experiment, run_id=automl_image_run.id + '_HD')
hyperdrive_run
# Out:
# Run(Experiment: AutoMLImages-SoundAnomaly,
# Id: AutoML_07dbecc7-90a6-4381-b82d-e1bbbb45c985_HD,
# Type: hyperdrive,
# Status: Completed)

# %%
# Defining tags for the custom vision model
cvmodel_tags={"Data": "Images", 
              "Context" : "Sound Anomaly",
              "Task" : "Best AutoML Images",
              "Framework" : "AzureML AutoML for Images",
              "AutoML Metric" : "Accuracy"}

# %%
# Register the best model from the AutoML Vision run in ONNX file format
best_child_run = automl_image_run.get_best_child()

model = best_child_run.register_model(model_name = 'SoundAnomalyONNX',
                                      model_path = 'train_artifacts/model.onnx',
                                      description = 'Sound Anomaly',
                                      tags = cvmodel_tags)

# %%
# %mkdir model

# %%
# We can download the CV model ONNX
model.download(target_dir = 'model', exist_ok=True, exists_ok=None)
# Out:
# 'model/model.onnx'

# %%
# Checking the downloaded ONNX model file
# !ls model/model.onnx -l
# Out:
# -rwxrwxrwx 1 root root 86714947 Mar 21 11:55 model/model.onnx

# %%
# Defining tags for the custom vision model
cvmodel_tags={"Data": "Images", 
              "Context" : "Sound Anomaly",
              "Task" : "Best AutoML Images",
              "Framework" : "AzureML AutoML for Images",
              "AutoML Metric" : "Accuracy"}

# %%
# Register the best model from the AutoML Vision run
best_child_run = automl_image_run.get_best_child()
model_name = best_child_run.properties['model_name']

model = best_child_run.register_model(model_name = model_name,
                                      model_path='outputs/model.pt',
                                      description='Sound Anomaly',
                                      tags=cvmodel_tags)

# %%
# We can download the CV model
model.download(target_dir='model', exist_ok=True, exists_ok=None)
# Out:
# 'model/model.pt'

# %%
# Checking the downloaded .pt model file
# !ls model/model.pt -l
# Out:
# -rwxrwxrwx 1 root root 173129677 Mar 21 11:55 model/model.pt

# %% [markdown]
# ### Model informations from the Azure ML model repository

# %%
model
# Out:
# Model(workspace=Workspace.create(name='azuremlvision', subscription_id='70b8f39e-8863-49f7-b6ba-34a80799550c', resource_group='azuremlvision-rg'), name=AutoML07dbecc795, id=AutoML07dbecc795:1, version=1, tags={'Data': 'Images', 'Context': 'Sound Anomaly', 'Task': 'Best AutoML Images', 'Framework': 'AzureML AutoML for Images', 'AutoML Metric': 'Accuracy'}, properties={})

# %%
model.id
# Out:
# 'AutoML07dbecc795:1'

# %%
model.name
# Out:
# 'AutoML07dbecc795'

# %%
model.version
# Out:
# 1

# %%
model.tags
# Out:
# {'Data': 'Images',
#  'Context': 'Sound Anomaly',
#  'Task': 'Best AutoML Images',
#  'Framework': 'AzureML AutoML for Images',
#  'AutoML Metric': 'Accuracy'}

# %%
model.created_time
# Out:
# datetime.datetime(2022, 3, 21, 11, 55, 11, 575348, tzinfo=<isodate.tzinfo.Utc object at 0x7f9bec5ad780>)

# %% [markdown]
# ## 9. Deploy model as a web service
# Once you have your trained model, you can deploy the model on Azure. **You can deploy your trained model as a web service on Azure Container Instances ([ACI](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-container-instance)) or Azure Kubernetes Service ([AKS](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-kubernetes-service)).**<br><br> ACI is the perfect option for testing deployments, while AKS is better suited for for high-scale, production usage. <br><br>
# **In this tutorial, we will deploy the model as a web service in AKS.**
# You will need to first create an AKS compute cluster, or use an existing AKS cluster. <br>
# You can use either GPU or CPU VM SKUs for your deployment cluster

# %%
# %%time
from azureml.core.compute import ComputeTarget, AksCompute
from azureml.exceptions import ComputeTargetException

# Choose a name for your cluster
aks_name = "aks-cluster"

# Check to see if the cluster already exists
try:
    aks_target = ComputeTarget(workspace=ws, name=aks_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    # Provision AKS cluster with GPU machine
    prov_config = AksCompute.provisioning_configuration(vm_size="STANDARD_NC6", 
                                                        location="westeurope")
    # Create the cluster
    aks_target = ComputeTarget.create(workspace=ws, 
                                      name=aks_name, 
                                      provisioning_configuration=prov_config)
    aks_target.wait_for_completion(show_output=True)
# Out:
# Found existing compute target.
# CPU times: user 11.5 ms, sys: 0 ns, total: 11.5 ms
# Wall time: 176 ms

# %% [markdown]
# Next, you will need to define the inference configuration, that describes how to set up the web-service containing your model. You can use the scoring script and the environment from the training run in your inference config.
# You can then deploy the model as an AKS web service.

# %%
from azureml.core.model import InferenceConfig
from azureml.core.webservice import AksWebservice
from azureml.core.webservice import Webservice
from azureml.core.model import Model
from azureml.core.environment import Environment

endpoint_name='automlcv-machinesoundanomaly' # Name of the deployed model

aks_tags={"Data": "Images", 
          "Topic" : "Sound Anomaly", 
          "Task" : "Image Classification",
          "Framework" : "AutoML Images best model", 
          "AKS" : "True"}

aks_description="Computer vision model to detect Sound Anomaly"


best_child_run.download_file('outputs/scoring_file_v_1_0_0.py', output_file_path='model/score.py')
environment = best_child_run.get_environment()
inference_config = InferenceConfig(entry_script='model/score.py', environment=environment)

aks_config = AksWebservice.deploy_configuration(autoscale_enabled=True,                                                    
                                                cpu_cores=1,
                                                memory_gb=50,
                                                enable_app_insights=True,
                                                description=aks_description,
                                                tags=aks_tags)

# %%
# Checking the file we downloaded
# !ls model/score.py -l
# Out:
# -rwxrwxrwx 1 root root 1953 Mar 21 11:55 model/score.py

# %%
# Viewing the score.py file
with open('model/score.py', 'r') as f:
    print(f.read())
# Out:
# # ---------------------------------------------------------
# # Copyright (c) Microsoft Corporation. All rights reserved.
# # ---------------------------------------------------------
# import os
# import tempfile
# import logging
#
# from azureml.contrib.services.aml_request import rawhttp
# from azureml.automl.core.shared import logging_utilities
# from azureml.contrib.services.aml_response import AMLResponse
# from azureml.core.model import Model
#
# from azureml.automl.dnn.vision.common.utils import _set_logging_parameters
# from azureml.automl.dnn.vision.common.model_export_utils import load_model, run_inference
# from azureml.automl.dnn.vision.common.logging_utils import get_logger
#
# from azureml.automl.dnn.vision.classification.inference.score import _score_with_model
#
# TASK_TYPE = 'image-classification'
# logger = get_logger('azureml.automl.core.scoring_script_images')
#
#
# def init():
#     global model
#
#     # Set up logging
#     _set_logging_parameters(TASK_TYPE, {})
#
#     model_path = Model.get_model_path(model_name='AutoML07dbecc795')
#
#     try:
#         logger.info("Loading model from path: {}.".format(model_path))
#         model_settings = {"valid_resize_size": 256, "valid_crop_size": 224, "train_crop_size": 224}
#         model = load_model(TASK_TYPE, model_path, **model_settings)
#         logger.info("Loading successful.")
#     except Exception as e:
#         logging_utilities.log_traceback(e, logger)
#         raise
#
#
# @rawhttp
# def run(request):
#     logger.info("Request: [{0}]".format(request))
#     if request.method == 'GET':
#         response_body = str.encode(request.full_path)
#         return AMLResponse(response_body, 200)
#     elif request.method == 'POST':
#         request_body = request.get_data()
#         logger.info("Running inference.")
#         result = run_inference(model, request_body, _score_with_model)
#         logger.info("Finished inferencing.")
#         return AMLResponse(result, 200)
#     else:
#         return AMLResponse("bad request", 500)

# %% [markdown]
# ### Let's deploy the CV model into AKS

# %%
# %%time
aks_service = Model.deploy(ws,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aks_config,
                           deployment_target=aks_target,
                           name=endpoint_name,
                           overwrite=True)

aks_service.wait_for_deployment(show_output=True)

print("\nDone. Model is deployed. Ready to use!")
print("\nAKS service status=", aks_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2022-03-21 11:56:04+00:00 Creating Container Registry if not exists.
# 2022-03-21 11:56:04+00:00 Registering the environment.
# 2022-03-21 11:56:04+00:00 Use the existing image.
# 2022-03-21 11:56:07+00:00 Creating resources in AKS.
# 2022-03-21 11:56:08+00:00 Submitting deployment to compute.
# 2022-03-21 11:56:09+00:00 Checking the status of deployment automlcv-machinesoundanomaly..
# 2022-03-21 11:56:58+00:00 Checking the status of inference endpoint automlcv-machinesoundanomaly.
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
#
# Done. Model is deployed. Ready to use!
#
# AKS service status= Healthy
# CPU times: user 1.31 s, sys: 193 ms, total: 1.5 s
# Wall time: 1min 2s

# %% [markdown]
# > Usually it takes 2 or 3 minutes to deploy. You can see the endpoint in Azure ML Studio

# %%
#print("CV model endpoint:", aks_service.scoring_uri)
print("CV model endpoint properties:", aks_service.properties)
print("CV model endpoint tags:", aks_service.tags)

# %%
# You can have access to the logs
#print(aks_service.get_logs())

# %%
print("Our CV model endpoint:", aks_service.scoring_uri)
print("\nStatus=", aks_service.state)
# Out:
# Our CV model endpoint: http://51.105.200.27:80/api/v1/service/automlcv-machinesoundanomaly/score
#
# Status= Healthy

# %% [markdown]
# ## 11. Clean up ressources

# %%
#aks_service.delete()

# %%
compute_target.delete()

# %% [markdown]
# > End of notebook
