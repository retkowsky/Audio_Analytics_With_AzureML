# %% [markdown]
# # Music Genre Classification
#
# ## 5. AutoML for Images
#
# <img src='music.jpg' width = 600>
#
# <div class="alert alert-info"> <b> In this notebook we will build, train and deploy an images classification model using AutoML for Images on the spectograms images.</b></div>
#
# Serge Retkowsky | serge.retkowsky@microsoft.com | 02-Mar-2022 | V1

# %% [markdown]
# ## What is AutoML for Images?

# %% [markdown]
# <img src="https://github.com/retkowsky/AutoMLforImages/blob/main/images/AutoML%20for%20Images.png?raw=true" width=700>

# %% [markdown]
# - Setup AutoML for Images:
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models
# - Documentation:
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#model-specific-hyperparameters
# - Supported Algorithms:
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#supported-model-algorithms

# %% [markdown]
# ## 1. Informations

# %%
import numpy as np
import json
import os
import urllib
from zipfile import ZipFile
import pandas as pd
import time

# %%
import sys
print("Python version =", sys.version)
# Out:
# Python version = 3.6.6 |Anaconda, Inc.| (default, Oct  9 2018, 12:34:16)
# [GCC 7.3.0]

# %%
# Your local platform
import platform,socket,re,uuid,json,psutil,logging

def getSystemInfo():
    try:
        info={}
        info['Platform']=platform.system()
        info['Platform-release']=platform.release()
        info['Platform-version']=platform.version()
        info['Architecture']=platform.machine()
        info['Hostname']=socket.gethostname()
        info['IP-address']=socket.gethostbyname(socket.gethostname())
        info['MAC-address']=':'.join(re.findall('..', '%012x' % uuid.getnode()))
        info['Processor']=platform.processor()
        info['RAM']=str(round(psutil.virtual_memory().total / (1024.0 **3)))+" Go"
        return json.dumps(info)
    except Exception as e:
        logging.exception(e)

json.loads(getSystemInfo())
# Out:
# {'Platform': 'Linux',
#  'Platform-release': '5.4.0-1056-azure',
#  'Platform-version': '#58~18.04.1-Ubuntu SMP Wed Jul 28 23:14:18 UTC 2021',
#  'Architecture': 'x86_64',
#  'Hostname': 'seretkow9',
#  'IP-address': '127.0.0.1',
#  'MAC-address': '00:0d:3a:bb:38:dc',
#  'Processor': 'x86_64',
#  'RAM': '14 Go'}

# %%
def filedir(LOCALFILE):
    timefile1 = os.path.getmtime(LOCALFILE)
    timefile = time.ctime(timefile1)
    timefile = time.strptime(timefile)
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S", timefile)
    file_size = os.path.getsize(LOCALFILE)
    file_size_mb = str(round(file_size/1024**2, 2))
    print(LOCALFILE, '|', timestamp, '|', file_size_mb, 'Mb')

# %%
import azureml.core
print("You are using Azure ML version", azureml.core.VERSION)
# Out:
# You are using Azure ML version 1.35.0

# %% [markdown]
# ## 2. Workspace setup
# In order to train and deploy models in Azure ML, you will first need to set up a workspace.
#
# An [Azure ML Workspace](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#workspace) is an Azure resource that organizes and coordinates the actions of many other Azure resources to assist in executing and sharing machine learning workflows. In particular, an Azure ML Workspace coordinates storage, databases, and compute resources providing added functionality for machine learning experimentation, deployment, inference, and the monitoring of deployed models.
#
# > Create an Azure ML Workspace within your Azure subscription, or load an existing workspace.

# %%
subscription_id = os.environ.get("SUBSCRIPTION_ID", "tobereplaced")
resource_group = os.environ.get("RESOURCE_GROUP", "azuremlvision-rg")
workspace_name = os.environ.get("WORKSPACE_NAME", "azuremlvision")

# %%
from azureml.core import Workspace
try:
    ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
    ws.write_config()
    print("OK")
except:
    print("Error: Workspace not found")
# Out:
# OK

# %%
from azureml.core import Workspace
ws = Workspace.from_config()

# %%
ws.name, ws.resource_group
# Out:
# ('azuremlvision', 'azuremlvision-rg')

# %% [markdown]
# ## 3. Azure ML GPU Compute target setup
# **You will need to provide a [Compute Target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) that will be used for your AutoML model training.** <br><br>
# **AutoML models for image tasks require GPU SKUs and support NC and ND families.** We recommend using the NCsv3-series (with v100 GPUs) for faster training. Using a compute target with a multi-GPU VM SKU will leverage the multiple GPUs to speed up training. Additionally, setting up a compute target with multiple nodes will allow for faster model training by leveraging parallelism, when tuning hyperparameters for your model.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

cluster_name = "AutoML-GPU"

try:
    compute_target = ws.compute_targets[cluster_name]
    print('Found existing compute target.')
except KeyError:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_NC6', # GPU cluster
                                                           idle_seconds_before_scaledown=1800, # Time out
                                                           min_nodes=0, 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

# Can poll for a minimum number of nodes and for a specific timeout.
# If no min_node_count is provided, it will use the scale settings for the cluster.
compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Creating a new compute target...
# InProgress.
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
# Compute status
compute_target.provisioning_state
# Out:
# 'Succeeded'

# %%
# Compute cluster information
compute_target.get_status().serialize()
# Out:
# {'currentNodeCount': 0,
#  'targetNodeCount': 0,
#  'nodeStateCounts': {'preparingNodeCount': 0,
#   'runningNodeCount': 0,
#   'idleNodeCount': 0,
#   'unusableNodeCount': 0,
#   'leavingNodeCount': 0,
#   'preemptedNodeCount': 0},
#  'allocationState': 'Resizing',
#  'allocationStateTransitionTime': '2022-03-21T09:21:21.269000+00:00',
#  'errors': None,
#  'creationTime': '2022-03-21T09:21:20.779642+00:00',
#  'modifiedTime': '2022-03-21T09:21:24.445583+00:00',
#  'provisioningState': 'Succeeded',
#  'provisioningStateTransitionTime': None,
#  'scaleSettings': {'minNodeCount': 0,
#   'maxNodeCount': 4,
#   'nodeIdleTimeBeforeScaleDown': 'PT1800S'},
#  'vmPriority': 'Dedicated',
#  'vmSize': 'STANDARD_NC6'}

# %%
# Compute VM size
compute_target.vm_size
# Out:
# 'STANDARD_NC6'

# %% [markdown]
# ## 4. Experiment Setup
# Create an [Experiment](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#experiment) in your workspace to track your model training runs

# %%
from azureml.core import Experiment

experiment_name = 'AutoMLImages-MusicGenreClassification' #Name of your experimentation
experiment = Experiment(ws, name=experiment_name)

# %%
experiment
# Out:
# Experiment(Name: AutoMLImages-MusicGenreClassification,
# Workspace: azuremlvision)

# %% [markdown]
# ## 5. Dataset with input Training Data
# In order to generate models for computer vision, you will need to bring in labeled image data as input for model training in the form of an AzureML Labeled Dataset. You can either use a Labeled Dataset that you have exported from a Data Labeling project, or create a new Labeled Dataset with your labeled training data

# %%
os.chdir('spectogramsmusicgenres')

# %%
# We have some images for the tags in directories we want to detect
print(os.listdir('.'))
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock', 'train_annotations.jsonl', 'validation_annotations.jsonl']

# %%
for root, _, files in os.walk('.'):
    print("Dir:", root, " = ", len(files), "images files.")
# Out:
# Dir: .  =  2 images files.
# Dir: ./blues  =  100 images files.
# Dir: ./classical  =  100 images files.
# Dir: ./country  =  100 images files.
# Dir: ./disco  =  100 images files.
# Dir: ./hiphop  =  100 images files.
# Dir: ./jazz  =  100 images files.
# Dir: ./metal  =  100 images files.
# Dir: ./pop  =  100 images files.
# Dir: ./reggae  =  100 images files.
# Dir: ./rock  =  100 images files.

# %%
from IPython.display import Image
sample_image = 'blues/blues.00000.jpg'
Image(filename=sample_image)

# %%
from IPython.display import Image
sample_image = 'rock/rock.00000.jpg'
Image(filename=sample_image)

# %%
from IPython.display import Image
sample_image = 'classical/classical.00000.jpg'
Image(filename=sample_image)

# %% [markdown]
# ### Convert the downloaded data to JSONL

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/mnt/batch/tasks/shared/LS_root/mounts/clusters/seretkow9/code/Users/seretkow/Sound/MusicGenreClassification'

# %%
src = "spectogramsmusicgenres/"

train_validation_ratio = 5

# Retrieving default datastore that got automatically created when we setup a workspace
workspaceblobstore = ws.get_default_datastore().name

# Path to the training and validation files
train_annotations_file = os.path.join(src, "train_annotations.jsonl")
validation_annotations_file = os.path.join(src, "validation_annotations.jsonl")

# sample json line dictionary
json_line_sample = \
    {
        "image_url": "AmlDatastore://" + workspaceblobstore + "/"
                     + os.path.basename(os.path.dirname(src)),
        "label": "",
        "label_confidence": 1.0
    }

index = 0
# Scan each sub directary and generate jsonl line
with open(train_annotations_file, 'w') as train_f:
    with open(validation_annotations_file, 'w') as validation_f:
        for className in os.listdir(src):
            subDir = src + className
            if not os.path.isdir(subDir):
                continue
            # Scan each sub directary
            print("Parsing " + subDir)
            for image in os.listdir(subDir):
                json_line = dict(json_line_sample)
                json_line["image_url"] += f"/{className}/{image}"
                json_line["label"] = className

                if index % train_validation_ratio == 0:
                    # validation annotation
                    validation_f.write(json.dumps(json_line) + "\n")
                else:
                    # train annotation
                    train_f.write(json.dumps(json_line) + "\n")
                index += 1
# Out:
# Parsing spectogramsmusicgenres/blues
# Parsing spectogramsmusicgenres/classical
# Parsing spectogramsmusicgenres/country
# Parsing spectogramsmusicgenres/disco
# Parsing spectogramsmusicgenres/hiphop
# Parsing spectogramsmusicgenres/jazz
# Parsing spectogramsmusicgenres/metal
# Parsing spectogramsmusicgenres/pop
# Parsing spectogramsmusicgenres/reggae
# Parsing spectogramsmusicgenres/rock

# %% [markdown]
# ### Upload the JSONL file and images to Datastore
# In order to use the data for training in Azure ML, we upload it to our Azure ML Workspace via a [Datastore](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores). The datastore provides a mechanism for you to upload/download data, and interact with it from your remote compute targets. It is an abstraction over Azure Storage.

# %%
# Retrieving default datastore that got automatically created when we setup a workspace
ds = ws.get_default_datastore()
ds.upload(src_dir='./spectogramsmusicgenres/', target_path='spectogramsmusicgenres')
# Out:
# Uploading an estimated of 1002 files
# Target already exists. Skipping upload for spectogramsmusicgenres/train_annotations.jsonl
# Target already exists. Skipping upload for spectogramsmusicgenres/validation_annotations.jsonl
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00000.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00001.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00002.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00003.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00004.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00005.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00006.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00007.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00008.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00009.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00010.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00011.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00012.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00013.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00014.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00015.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00016.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00017.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00018.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00019.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00020.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00021.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00022.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00023.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00024.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00025.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00026.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00027.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00028.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00029.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00030.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00031.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00032.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00033.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00034.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00035.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00036.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00037.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00038.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00039.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00040.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00041.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00042.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00043.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00044.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00045.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00046.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00047.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00048.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00049.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00050.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00051.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00052.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00053.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00054.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00055.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00056.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00057.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00058.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00059.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00060.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00061.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00062.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00063.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00064.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00065.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00066.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00067.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00068.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00069.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00070.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00071.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00072.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00073.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00074.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00075.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00076.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00077.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00078.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00079.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00080.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00081.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00082.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00083.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00084.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00085.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00086.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00087.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00088.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00089.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00090.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00091.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00092.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00093.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00094.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00095.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00096.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00097.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00098.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/blues/blues.00099.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00000.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00001.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00002.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00003.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00004.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00005.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00006.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00007.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00008.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00009.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00010.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00011.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00012.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00013.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00014.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00015.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00016.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00017.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00018.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00019.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00020.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00021.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00022.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00023.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00024.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00025.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00026.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00027.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00028.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00029.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00030.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00031.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00032.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00033.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00034.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00035.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00036.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00037.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00038.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00039.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00040.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00041.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00042.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00043.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00044.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00045.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00046.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00047.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00048.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00049.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00050.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00051.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00052.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00053.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00054.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00055.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00056.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00057.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00058.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00059.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00060.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00061.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00062.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00063.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00064.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00065.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00066.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00067.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00068.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00069.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00070.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00071.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00072.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00073.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00074.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00075.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00076.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00077.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00078.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00079.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00080.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00081.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00082.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00083.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00084.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00085.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00086.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00087.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00088.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00089.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00090.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00091.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00092.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00093.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00094.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00095.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00096.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00097.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00098.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/classical/classical.00099.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00000.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00001.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00002.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00003.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00004.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00005.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00006.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00007.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00008.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00009.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00010.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00011.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00012.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00013.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00014.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00015.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00016.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00017.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00018.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00019.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00020.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00021.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00022.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00023.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00024.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00025.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00026.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00027.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00028.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00029.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00030.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00031.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00032.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00033.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00034.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00035.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00036.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00037.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00038.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00039.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00040.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00041.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00042.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00043.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00044.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00045.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00046.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00047.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00048.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00049.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00050.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00051.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00052.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00053.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00054.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00055.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00056.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00057.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00058.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00059.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00060.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00061.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00062.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00063.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00064.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00065.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00066.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00067.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00068.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00069.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00070.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00071.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00072.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00073.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00074.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00075.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00076.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00077.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00078.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00079.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00080.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00081.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00082.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00083.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00084.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00085.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00086.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00087.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00088.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00089.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00090.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00091.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00092.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00093.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00094.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00095.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00096.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00097.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00098.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/country/country.00099.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00000.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00001.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00002.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00003.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00004.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00005.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00006.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00007.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00008.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00009.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00010.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00011.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00012.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00013.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00014.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00015.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00016.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00017.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00018.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00019.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00020.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00021.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00022.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00023.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00024.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00025.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00026.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00027.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00028.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00029.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00030.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00031.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00032.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00033.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00034.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00035.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00036.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00037.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00038.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00039.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00040.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00041.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00042.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00043.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00044.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00045.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00046.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00047.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00048.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00049.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00050.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00051.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00052.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00053.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00054.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00055.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00056.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00057.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00058.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00059.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00060.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00061.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00062.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00063.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00064.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00065.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00066.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00067.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00068.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00069.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00070.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00071.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00072.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00073.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00074.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00075.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00076.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00077.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00078.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00079.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00080.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00081.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00082.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00083.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00084.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00085.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00086.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00087.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00088.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00089.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00090.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00091.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00092.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00093.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00094.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00095.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00096.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00097.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00098.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/disco/disco.00099.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00000.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00001.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00002.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00003.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00004.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00005.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00006.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00007.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00008.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00009.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00010.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00011.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00012.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00013.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00014.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00015.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00016.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00017.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00018.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00019.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00020.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00021.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00022.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00023.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00024.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00025.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00026.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00027.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00028.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00029.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00030.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00031.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00032.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00033.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00034.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00035.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00036.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00037.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00038.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00039.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00040.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00041.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00042.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00043.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00044.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00045.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00046.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00047.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00048.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00049.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00050.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00051.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00052.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00053.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00054.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00055.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00056.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00057.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00058.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00059.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00060.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00061.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00062.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00063.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00064.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00065.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00066.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00067.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00068.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00069.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00070.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00071.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00072.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00073.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00074.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00075.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00076.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00077.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00078.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00079.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00080.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00081.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00082.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00083.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00084.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00085.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00086.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00087.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00088.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00089.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00090.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00091.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00092.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00093.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00094.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00095.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00096.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00097.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00098.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/hiphop/hiphop.00099.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00000.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00001.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00002.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00003.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00004.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00005.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00006.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00007.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00008.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00009.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00010.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00011.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00012.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00013.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00014.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00015.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00016.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00017.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00018.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00019.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00020.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00021.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00022.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00023.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00024.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00025.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/jazz/jazz.00026.jpg
# ...
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00019.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00020.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00021.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00022.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00023.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00024.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00025.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00026.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00027.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00028.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00029.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00030.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00031.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00032.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00033.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00034.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00035.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00036.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00037.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00038.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00039.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00040.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00041.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00042.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00043.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00044.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00045.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00046.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00047.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00048.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00049.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00050.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00051.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00052.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00053.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00054.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00055.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00056.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00057.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00058.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00059.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00060.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00061.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00062.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00063.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00064.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00065.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00066.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00067.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00068.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00069.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00070.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00071.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00072.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00073.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00074.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00075.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00076.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00077.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00078.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00079.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00080.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00081.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00082.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00083.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00084.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00085.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00086.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00087.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00088.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00089.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00090.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00091.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00092.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00093.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00094.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00095.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00096.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00097.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00098.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/reggae/reggae.00099.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00000.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00001.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00002.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00003.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00004.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00005.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00006.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00007.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00008.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00009.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00010.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00011.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00012.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00013.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00014.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00015.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00016.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00017.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00018.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00019.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00020.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00021.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00022.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00023.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00024.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00025.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00026.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00027.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00028.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00029.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00030.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00031.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00032.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00033.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00034.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00035.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00036.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00037.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00038.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00039.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00040.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00041.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00042.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00043.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00044.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00045.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00046.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00047.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00048.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00049.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00050.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00051.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00052.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00053.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00054.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00055.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00056.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00057.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00058.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00059.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00060.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00061.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00062.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00063.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00064.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00065.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00066.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00067.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00068.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00069.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00070.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00071.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00072.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00073.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00074.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00075.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00076.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00077.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00078.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00079.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00080.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00081.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00082.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00083.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00084.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00085.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00086.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00087.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00088.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00089.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00090.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00091.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00092.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00093.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00094.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00095.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00096.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00097.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00098.jpg
# Target already exists. Skipping upload for spectogramsmusicgenres/rock/rock.00099.jpg
# Uploaded 0 files
# $AZUREML_DATAREFERENCE_236d2e04513b4c598f693e7ac6cbcc1a

# %%
ds
# Out:
# {
#   "name": "workspaceblobstore",
#   "container_name": "azureml-blobstore-c3c87d4d-5b7e-436b-8a1a-5765a35e9878",
#   "account_name": "azuremlvision8724517013",
#   "protocol": "https",
#   "endpoint": "core.windows.net"
# }

# %% [markdown]
# Finally, we need to create an Azure ML [Dataset](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores) from the data we uploaded to the Datastore. We create one dataset for training and one for validation.

# %%
from azureml.contrib.dataset.labeled_dataset import _LabeledDatasetFactory, LabeledDatasetTask
from azureml.core import Dataset

training_dataset_name = 'musicgenreTrainingDataset'

if training_dataset_name in ws.datasets:
    training_dataset = ws.datasets.get(training_dataset_name)
    print('Found the training dataset', training_dataset_name)

else:
    # create training dataset
    training_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('spectogramsmusicgenres/train_annotations.jsonl'))
    training_dataset = training_dataset.register(workspace=ws, name=training_dataset_name)
    
# create validation dataset
validation_dataset_name = "musicgenreValidationDataset"

if validation_dataset_name in ws.datasets:
    validation_dataset = ws.datasets.get(validation_dataset_name)
    print('Found the validation dataset', validation_dataset_name)

else:
    validation_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('spectogramsmusicgenres/validation_annotations.jsonl'))
    validation_dataset = validation_dataset.register(workspace=ws, name=validation_dataset_name)

print("\nTraining dataset name:" + training_dataset.name)
print("Validation dataset name:" + validation_dataset.name)
# Out:
# Found the training dataset musicgenreTrainingDataset
# Found the validation dataset musicgenreValidationDataset
#
# Training dataset name:musicgenreTrainingDataset
# Validation dataset name:musicgenreValidationDataset

# %% [markdown]
# Validation dataset is optional. If no validation dataset is specified, by default 20% of your training data will be used for validation. You can control the percentage using the `split_ratio` argument - please refer to the documentation for more details.
#
# This is what the training dataset looks like

# %%
images=training_dataset.to_pandas_dataframe()

# %%
images.shape
# Out:
# (800, 3)

# %%
images.head()
# Out:
#                                            image_url  label  label_confidence
# 0  StreamInfo(AmlDatastore://spectogramsmusicgenr...  blues               1.0
# 1  StreamInfo(AmlDatastore://spectogramsmusicgenr...  blues               1.0
# 2  StreamInfo(AmlDatastore://spectogramsmusicgenr...  blues               1.0
# 3  StreamInfo(AmlDatastore://spectogramsmusicgenr...  blues               1.0
# 4  StreamInfo(AmlDatastore://spectogramsmusicgenr...  blues               1.0

# %%
images['label'].value_counts()
# Out:
# disco        80
# classical    80
# blues        80
# jazz         80
# pop          80
# reggae       80
# rock         80
# metal        80
# country      80
# hiphop       80
# Name: label, dtype: int64

# %%
# Percentage values
images['label'].value_counts(normalize=True)
# Out:
# disco        0.1
# classical    0.1
# blues        0.1
# jazz         0.1
# pop          0.1
# reggae       0.1
# rock         0.1
# metal        0.1
# country      0.1
# hiphop       0.1
# Name: label, dtype: float64

# %%
from IPython.display import Image
# %matplotlib inline
import matplotlib.pyplot as plt
images['label'].value_counts(sort=True).plot.bar()

# %% [markdown]
# ## 6. Configuring your AutoML run for image tasks
# AutoML allows you to easily train models for Image Classification, Object Detection & Instance Segmentation on your image data. You can control the model algorithm to be used, specify hyperparameter values for your model as well as perform a sweep across the hyperparameter space to generate an optimal model. Parameters for configuring your AutoML runs for image related tasks are specified using the 'AutoMLImageConfig' - please refer to the [documentation](https://github.com/swatig007/automlForImages#readme) for the details on the parameters that can be used and their values.

# %% [markdown]
# When using AutoML for image tasks, you need to specify the model algorithms using the `model_name` parameter. You can either specify a single model or choose to sweep over multiple ones.<br><br>
#
# ### Using default hyperparameter values for the specified algorithm
#
# Before doing a large sweep to search for the optimal models and hyperparameters, we recommend trying the default values to get a first baseline. Next, you can explore multiple hyperparameters for the same model before sweeping over multiple models and their parameters. This is for employing a more iterative approach, because with multiple models and multiple hyperparameters for each (as we showcase in the next section), the search space grows exponentially and you need more iterations to find optimal configurations.

# %% [markdown]
# Supported Algorithms
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#supported-model-algorithms

# %%
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import RandomParameterSampling
from azureml.train.hyperdrive import GridParameterSampling
from azureml.train.hyperdrive import choice
from azureml.automl.core.shared.constants import ImageTask

# %%
# AutoML Configuration
image_config = AutoMLImageConfig(task=ImageTask.IMAGE_CLASSIFICATION, # AutoML Vision task
                                 compute_target=compute_target, # Compute target
                                 training_data=training_dataset, # Training dataset
                                 validation_data=validation_dataset, # Validation dataset
                                 hyperparameter_sampling=GridParameterSampling({'model_name': choice('seresnext')}),
                                 iterations=1)

# %% [markdown]
# ## 7. Submitting an AutoML run for Computer Vision tasks
# Once you've created the config settings for your run, **you can submit an AutoML run** using the config in order to train a vision model using your training dataset.

# %%
automl_image_run = experiment.submit(image_config)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>AutoMLImages-MusicGenreClassification</td><td>AutoML_d54a7fe2-b0ca-4bea-a93c-968e9aa1e5f0</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_d54a7fe2-b0ca-4bea-a93c-968e9aa1e5f0?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlvision-rg/workspaces/azuremlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True) # Wait until automl run is finished
# Out:
# {'runId': 'AutoML_d54a7fe2-b0ca-4bea-a93c-968e9aa1e5f0',
#  'target': 'AutoML-GPU',
#  'status': 'Completed',
#  'startTimeUtc': '2022-03-21T09:22:43.012902Z',
#  'endTimeUtc': '2022-03-21T09:44:14.925076Z',
#  'services': {},
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'AutoML-GPU',
#   'AMLSettingsJsonString': '{"path":null,"name":"AutoMLImages-MusicGenreClassification","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"azuremlvision-rg","workspace_name":"azuremlvision","region":"westeurope","compute_target":"AutoML-GPU","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":true,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"accuracy","task_type":"image-classification","positive_label":null,"data_script":null,"test_size":0.0,"test_include_predictions_only":false,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"enable_categorical_indicators":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":true,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"67a9f03f-40e4-4eee-bd8b-4fb72e052010","hyperdrive_config":{"max_total_jobs":1,"max_concurrent_jobs":1,"generator_config":{"name":"GRID","parameter_space":"{\\"model_name\\": [\\"choice\\", [[\\"seresnext\\"]]]}","properties":null},"policy_config":null},"validation_dataset_id":"5952feac-4abf-4b2c-aba2-0e642c350826","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"67a9f03f-40e4-4eee-bd8b-4fb72e052010\\"}, \\"validation_data\\": {\\"datasetId\\": \\"5952feac-4abf-4b2c-aba2-0e642c350826\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'AutoMLImageSDK',
#   'display_task_type': 'image-classification',
#   'dependencies_versions': '{"azureml-widgets": "1.35.0", "azureml-train-restclients-hyperdrive": "1.35.0", "azureml-train-core": "1.35.0", "azureml-train-automl-runtime": "1.35.1", "azureml-train-automl-client": "1.35.0", "azureml-telemetry": "1.35.0", "azureml-pipeline-steps": "1.35.0", "azureml-pipeline-core": "1.35.0", "azureml-mlflow": "1.35.0", "azureml-interpret": "1.35.0", "azureml-inference-server-http": "0.3.2", "azureml-defaults": "1.35.0", "azureml-dataset-runtime": "1.35.0", "azureml-dataprep": "2.23.2", "azureml-dataprep-rslex": "1.21.2", "azureml-dataprep-native": "38.0.0", "azureml-core": "1.35.0.post1", "azureml-contrib-dataset": "1.35.0", "azureml-contrib-automl-pipeline-steps": "1.35.1", "azureml-automl-runtime": "1.35.1", "azureml-automl-core": "1.35.1"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'AutoMLImageSDK',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/azuremlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/azuremlvision/experimentids/7b347e7a-d90b-4bb9-8626-1401ecd5b902/cancel/AutoML_d54a7fe2-b0ca-4bea-a93c-968e9aa1e5f0',
#   'ClientSdkVersion': '1.39.1',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': '67a9f03f-40e4-4eee-bd8b-4fb72e052010'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': '5952feac-4abf-4b2c-aba2-0e642c350826'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %%
automl_image_run.id
# Out:
# 'AutoML_d54a7fe2-b0ca-4bea-a93c-968e9aa1e5f0'

# %%
experiment
# Out:
# Experiment(Name: AutoMLImages-MusicGenreClassification,
# Workspace: azuremlvision)

# %%
best_child_run=automl_image_run.get_best_child()
best_child_run.download_file("confusion_matrix", output_file_path = "confusion_matrix_automl1.json")

# %%
# List of all the AutoML for Images metrics values
automlvisionmetrics = automl_image_run.get_metrics()
automlvisionmetrics
# Out:
# {'recall_score_macro': [0.245,
#   0.51,
#   0.56,
#   0.615,
#   0.55,
#   0.66,
#   0.69,
#   0.66,
#   0.705,
#   0.735,
#   0.75,
#   0.745,
#   0.765,
#   0.795,
#   0.78],
#  'precision_score_micro': [0.245,
#   0.51,
#   0.56,
#   0.615,
#   0.55,
#   0.66,
#   0.69,
#   0.66,
#   0.705,
#   0.735,
#   0.75,
#   0.745,
#   0.765,
#   0.795,
#   0.78],
#  'precision_score_weighted': [0.25713,
#   0.49783,
#   0.58417,
#   0.67141,
#   0.5801,
#   0.73201,
#   0.70403,
#   0.66258,
#   0.71804,
#   0.74086,
#   0.8158,
#   0.74234,
#   0.7739,
#   0.80136,
#   0.77856],
#  'AUC_micro': [0.66631,
#   0.85848,
#   0.91255,
#   0.92438,
#   0.88329,
#   0.94381,
#   0.95724,
#   0.94906,
#   0.96374,
#   0.96682,
#   0.96309,
#   0.96733,
#   0.96906,
#   0.97045,
#   0.97106],
#  'recall_score_micro': [0.245,
#   0.51,
#   0.56,
#   0.615,
#   0.55,
#   0.66,
#   0.69,
#   0.66,
#   0.705,
#   0.735,
#   0.75,
#   0.745,
#   0.765,
#   0.795,
#   0.78],
#  'average_precision_score_weighted': [0.31939,
#   0.5673,
#   0.67624,
#   0.71253,
#   0.62184,
#   0.78855,
#   0.78837,
#   0.74899,
#   0.78764,
#   0.8206,
#   0.81644,
#   0.82015,
#   0.8399,
#   0.84092,
#   0.8402],
#  'recall_score_weighted': [0.245,
#   0.51,
#   0.56,
#   0.615,
#   0.55,
#   0.66,
#   0.69,
#   0.66,
#   0.705,
#   0.735,
#   0.75,
#   0.745,
#   0.765,
#   0.795,
#   0.78],
#  'f1_score_micro': [0.245,
#   0.51,
#   0.56,
#   0.615,
#   0.55,
#   0.66,
#   0.69,
#   0.66,
#   0.705,
#   0.735,
#   0.75,
#   0.745,
#   0.765,
#   0.795,
#   0.78],
#  'f1_score_weighted': [0.18877,
#   0.46976,
#   0.53429,
#   0.60477,
#   0.51441,
#   0.66399,
#   0.68664,
#   0.63807,
#   0.70495,
#   0.73124,
#   0.75223,
#   0.73557,
#   0.76259,
#   0.79435,
#   0.77711],
#  'f1_score_macro': [0.18877,
#   0.46976,
#   0.53429,
#   0.60477,
#   0.51441,
#   0.66399,
#   0.68664,
#   0.63807,
#   0.70495,
#   0.73124,
#   0.75223,
#   0.73557,
#   0.76259,
#   0.79435,
#   0.77711],
#  'accuracy': [0.245,
#   0.51,
#   0.56,
#   0.615,
#   0.55,
#   0.66,
#   0.69,
#   0.66,
#   0.705,
#   0.735,
#   0.75,
#   0.745,
#   0.765,
#   0.795,
#   0.78],
#  'average_precision_score_micro': [0.23726,
#   0.54375,
#   0.63889,
#   0.70049,
#   0.57021,
#   0.74266,
#   0.79744,
#   0.75332,
#   0.81238,
#   0.83373,
#   0.81821,
#   0.83587,
#   0.84858,
#   0.85734,
#   0.85878],
#  'log_loss_train': [2.29942,
#   2.03585,
#   1.53222,
#   1.33067,
#   1.12954,
#   1.12912,
#   1.10828,
#   0.91951,
#   0.85577,
#   0.82187,
#   0.81263,
#   0.65988,
#   0.69816,
#   0.65036,
#   0.67787],
#  'AUC_weighted': [0.71306,
#   0.86811,
#   0.91344,
#   0.92261,
#   0.89047,
#   0.94481,
#   0.95289,
#   0.94342,
#   0.95492,
#   0.96078,
#   0.95675,
#   0.96122,
#   0.96489,
#   0.96542,
#   0.96589],
#  'accuracy_train': [0.125,
#   0.285,
#   0.48125,
#   0.5275,
#   0.59375,
#   0.61625,
#   0.63125,
#   0.67375,
#   0.71375,
#   0.7075,
#   0.71,
#   0.76875,
#   0.74625,
#   0.775,
#   0.77],
#  'classification_report': {'class_name': ['blues',
#    'classical',
#    'country',
#    'disco',
#    'hiphop',
#    'jazz',
#    'metal',
#    'pop',
#    'reggae',
#    'rock',
#    'micro avg',
#    'macro avg',
#    'weighted avg'],
#   'precision': [0.80952,
#    0.95238,
#    0.61905,
#    0.64286,
#    0.89474,
#    0.9,
#    1.0,
#    0.84211,
#    0.70588,
#    0.64706,
#    0.795,
#    0.80136,
#    0.80136],
#   'recall': [0.85,
#    1.0,
#    0.65,
#    0.9,
#    0.85,
#    0.9,
#    0.85,
#    0.8,
#    0.6,
#    0.55,
#    0.795,
#    0.795,
#    0.795],
#   'f1-score': [0.82927,
#    0.97561,
#    0.63415,
#    0.75,
#    0.87179,
#    0.9,
#    0.91892,
#    0.82051,
#    0.64865,
#    0.59459,
#    0.795,
#    0.79435,
#    0.79435],
#   'support': [20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    200.0,
#    200.0,
#    200.0],
#   'auc': [0.98778,
#    0.99972,
#    0.94167,
#    0.97333,
#    0.9425,
#    0.99556,
#    0.99528,
#    0.98472,
#    0.94667,
#    0.88694,
#    0.97045,
#    0.96542,
#    0.96542],
#   'average_precision': [0.9239,
#    0.99762,
#    0.64213,
#    0.82268,
#    0.84596,
#    0.97102,
#    0.96643,
#    0.84427,
#    0.79883,
#    0.59634,
#    0.85734,
#    0.84092,
#    0.84092]},
#  'average_precision_score_macro': [0.31939,
#   0.5673,
#   0.67624,
#   0.71253,
#   0.62184,
#   0.78855,
#   0.78837,
#   0.74899,
#   0.78764,
#   0.8206,
#   0.81644,
#   0.82015,
#   0.8399,
#   0.84092,
#   0.8402],
#  'AUC_macro': [0.71306,
#   0.86811,
#   0.91344,
#   0.92261,
#   0.89047,
#   0.94481,
#   0.95289,
#   0.94342,
#   0.95492,
#   0.96078,
#   0.95675,
#   0.96122,
#   0.96489,
#   0.96542,
#   0.96589],
#  'precision_score_macro': [0.25713,
#   0.49783,
#   0.58417,
#   0.67141,
#   0.5801,
#   0.73201,
#   0.70403,
#   0.66258,
#   0.71804,
#   0.74086,
#   0.8158,
#   0.74234,
#   0.7739,
#   0.80136,
#   0.77856],
#  'log_loss': [2.16354,
#   1.61912,
#   1.25513,
#   1.17577,
#   1.57943,
#   0.99786,
#   0.8657,
#   0.9861,
#   0.82558,
#   0.76295,
#   0.81957,
#   0.77038,
#   0.74424,
#   0.72179,
#   0.71366]}

# %%
automlvisionmetrics['classification_report']
# Out:
# {'class_name': ['blues',
#   'classical',
#   'country',
#   'disco',
#   'hiphop',
#   'jazz',
#   'metal',
#   'pop',
#   'reggae',
#   'rock',
#   'micro avg',
#   'macro avg',
#   'weighted avg'],
#  'precision': [0.80952,
#   0.95238,
#   0.61905,
#   0.64286,
#   0.89474,
#   0.9,
#   1.0,
#   0.84211,
#   0.70588,
#   0.64706,
#   0.795,
#   0.80136,
#   0.80136],
#  'recall': [0.85,
#   1.0,
#   0.65,
#   0.9,
#   0.85,
#   0.9,
#   0.85,
#   0.8,
#   0.6,
#   0.55,
#   0.795,
#   0.795,
#   0.795],
#  'f1-score': [0.82927,
#   0.97561,
#   0.63415,
#   0.75,
#   0.87179,
#   0.9,
#   0.91892,
#   0.82051,
#   0.64865,
#   0.59459,
#   0.795,
#   0.79435,
#   0.79435],
#  'support': [20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   200.0,
#   200.0,
#   200.0],
#  'auc': [0.98778,
#   0.99972,
#   0.94167,
#   0.97333,
#   0.9425,
#   0.99556,
#   0.99528,
#   0.98472,
#   0.94667,
#   0.88694,
#   0.97045,
#   0.96542,
#   0.96542],
#  'average_precision': [0.9239,
#   0.99762,
#   0.64213,
#   0.82268,
#   0.84596,
#   0.97102,
#   0.96643,
#   0.84427,
#   0.79883,
#   0.59634,
#   0.85734,
#   0.84092,
#   0.84092]}

# %%
# Let's plot the accuracy metric for the CV model, save the graph to a jpg file and log it to the Azure ML experiment
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15,8))
plt.plot(automlvisionmetrics['accuracy'], 'g-', lw=2, alpha=.6)
plt.xlabel('iterations', fontsize=10)
plt.ylabel('accuracy', fontsize=10)
plt.title('vitb16r224 CV model accuracy', fontsize=12)
plt.grid(color='#DDDDDD', linewidth = 0.8)
plt.xticks(np.arange(0, 15, 1))
plt.savefig('automl1_vitb16r224.jpg', dpi=150) # Saving image in a jpg file
automl_image_run.log_image(name='automl1_vitb16r224.jpg', plot=plt) # Logging the graph into the Azure ML experiment

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 8))
plt.plot(automlvisionmetrics['log_loss'], 'r-', lw = 2, alpha = .6)
plt.xlabel('Iterations', fontsize = 12)
plt.ylabel('Log Loss', fontsize = 12)
plt.title('Images Classification model - Log Loss', fontsize = 15)
plt.grid( color='#DDDDDD', linewidth = 0.8)
plt.xticks(np.arange(0, 15, 1))
plt.savefig('automl1_logloss.png')
plt.show()

# %%
# You can view the jpg file in the experiment
experiment
# Out:
# Experiment(Name: AutoMLImages-MusicGenreClassification,
# Workspace: azuremlvision)

# %% [markdown]
# ## Let's improve using additionals models & hyperparameter tuning

# %% [markdown]
# ### Hyperparameter sweeping for your AutoML models for computer vision tasks
#
# When using AutoML for Images, you can perform a hyperparameter sweep over a defined parameter space, to find the optimal model. In this example, we sweep over the hyperparameters for each algorithm, **choosing from a range of values for learning_rate, optimizer, lr_scheduler, etc, to generate a model with the optimal 'accuracy'.** If hyperparameter values are not specified, then default values are used for the specified algorithm.
#
# We use **Random Sampling to pick samples from this parameter space and try a total of 10 iterations** with these different samples, running 4 iterations at a time on our compute target, which has been previously set up using 4 nodes. Please note that the more parameters the space has, the more iterations you need to find optimal models.
#
# We also leverage the **Bandit early termination policy** that terminates poor performing configs (those that are not within 20% slack of the best perfroming config), thus significantly saving compute resources.

# %% [markdown]
# Supported Algorithms
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#supported-model-algorithms

# %%
from azureml.automl.core.shared.constants import ImageTask
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import BanditPolicy, RandomParameterSampling
from azureml.train.hyperdrive import choice, uniform

parameter_space = {
    "learning_rate": uniform(0.001, 0.01),
    "model": choice(
        {
            "model_name": choice("vitb16r224", "vits16r224"),
            "number_of_epochs": choice(15, 30),
        },
        {
            "model_name": choice("seresnext", "resnest50"),
            "layers_to_freeze": choice(0, 1, 2),
        },
    ),
}

tuning_settings = {
    "iterations": 10,
    "max_concurrent_iterations": 5,
    "hyperparameter_sampling": RandomParameterSampling(parameter_space),
    "early_termination_policy": BanditPolicy(
        evaluation_interval=2, slack_factor=0.2, delay_evaluation=6
    ),
}

automl_image_config = AutoMLImageConfig(
    task=ImageTask.IMAGE_CLASSIFICATION,
    compute_target=compute_target,
    training_data=training_dataset,
    validation_data=validation_dataset,
    **tuning_settings,
)

# %%
automl_image_run = experiment.submit(automl_image_config)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>AutoMLImages-MusicGenreClassification</td><td>AutoML_0e854488-29d1-48b6-b704-cc925f36322f</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_0e854488-29d1-48b6-b704-cc925f36322f?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/azuremlvision-rg/workspaces/azuremlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True)
# Out:
# {'runId': 'AutoML_0e854488-29d1-48b6-b704-cc925f36322f',
#  'target': 'AutoML-GPU',
#  'status': 'Completed',
#  'startTimeUtc': '2022-03-21T09:50:41.457633Z',
#  'endTimeUtc': '2022-03-21T10:31:59.66018Z',
#  'services': {},
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'AutoML-GPU',
#   'AMLSettingsJsonString': '{"path":null,"name":"AutoMLImages-MusicGenreClassification","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"azuremlvision-rg","workspace_name":"azuremlvision","region":"westeurope","compute_target":"AutoML-GPU","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":true,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"accuracy","task_type":"image-classification","positive_label":null,"data_script":null,"test_size":0.0,"test_include_predictions_only":false,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"enable_categorical_indicators":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":true,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"67a9f03f-40e4-4eee-bd8b-4fb72e052010","hyperdrive_config":{"max_total_jobs":10,"max_concurrent_jobs":5,"generator_config":{"name":"RANDOM","parameter_space":"{\\"learning_rate\\": [\\"uniform\\", [0.001, 0.01]], \\"model\\": [\\"choice\\", [[{\\"model_name\\": [\\"choice\\", [[\\"vitb16r224\\", \\"vits16r224\\"]]], \\"number_of_epochs\\": [\\"choice\\", [[15, 30]]]}, {\\"model_name\\": [\\"choice\\", [[\\"seresnext\\", \\"resnest50\\"]]], \\"layers_to_freeze\\": [\\"choice\\", [[0, 1, 2]]]}]]]}","properties":null},"policy_config":{"name":"Bandit","properties":{"evaluation_interval":2,"delay_evaluation":6,"slack_factor":0.2}}},"validation_dataset_id":"5952feac-4abf-4b2c-aba2-0e642c350826","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"67a9f03f-40e4-4eee-bd8b-4fb72e052010\\"}, \\"validation_data\\": {\\"datasetId\\": \\"5952feac-4abf-4b2c-aba2-0e642c350826\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'AutoMLImageSDK',
#   'display_task_type': 'image-classification',
#   'dependencies_versions': '{"azureml-widgets": "1.35.0", "azureml-train-restclients-hyperdrive": "1.35.0", "azureml-train-core": "1.35.0", "azureml-train-automl-runtime": "1.35.1", "azureml-train-automl-client": "1.35.0", "azureml-telemetry": "1.35.0", "azureml-pipeline-steps": "1.35.0", "azureml-pipeline-core": "1.35.0", "azureml-mlflow": "1.35.0", "azureml-interpret": "1.35.0", "azureml-inference-server-http": "0.3.2", "azureml-defaults": "1.35.0", "azureml-dataset-runtime": "1.35.0", "azureml-dataprep": "2.23.2", "azureml-dataprep-rslex": "1.21.2", "azureml-dataprep-native": "38.0.0", "azureml-core": "1.35.0.post1", "azureml-contrib-dataset": "1.35.0", "azureml-contrib-automl-pipeline-steps": "1.35.1", "azureml-automl-runtime": "1.35.1", "azureml-automl-core": "1.35.1"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'AutoMLImageSDK',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/azuremlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/azuremlvision/experimentids/7b347e7a-d90b-4bb9-8626-1401ecd5b902/cancel/AutoML_0e854488-29d1-48b6-b704-cc925f36322f',
#   'ClientSdkVersion': '1.39.1',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': '67a9f03f-40e4-4eee-bd8b-4fb72e052010'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': '5952feac-4abf-4b2c-aba2-0e642c350826'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %% [markdown]
# > When doing a hyperparameter sweep, **it can be useful to visualize the different configurations that were tried using the HyperDrive UI**. <br><br>You can navigate to this UI by going to the **'Child runs' tab in the UI of the main automl_image_run** from above, which is the HyperDrive parent run. Then you can go into the 'Child runs' tab of this one.

# %%
experiment
# Out:
# Experiment(Name: AutoMLImages-MusicGenreClassification,
# Workspace: azuremlvision)

# %% [markdown]
# ### You will see all the AutoML runs from the Child runs section.
# The **model column** will display detailled information about each model.<br>

# %% [markdown]
# > You can find all the artefacts from the output+logs section of Azure ML

# %%
# Let's plot the accuracy metric for the CV model, save the graph to a jpg file and log it to the Azure ML experiment
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 8))
plt.plot(automlvisionmetrics['accuracy'], 'g-', lw=2, alpha=.6)
plt.xlabel('iterations', fontsize=12)
plt.ylabel('accuracy', fontsize=12)
plt.title('Images Classification model - Accuracy', fontsize=15)
plt.grid(color='#DDDDDD', linewidth = 0.8)
plt.xticks(np.arange(0, 15, 1))
plt.savefig('automl2_vitb16r224.jpg', dpi=150) # Saving image in a jpg file
automl_image_run.log_image(name='automl2_vitb16r224.jpg', plot=plt) # Logging the graph into the Azure ML experiment

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 8))
plt.plot(automlvisionmetrics['log_loss'], 'r-', lw = 2, alpha = .6)
plt.xlabel('Iterations', fontsize = 12)
plt.ylabel('Log Loss', fontsize = 12)
plt.title('Images Classification model - Log Loss', fontsize = 15)
plt.grid( color='#DDDDDD', linewidth = 0.8)
plt.xticks(np.arange(0, 15, 1))
plt.savefig('automl2_logloss.png')
plt.show()

# %%
# List of all the AutoML for Images metrics values
automlvisionmetrics = automl_image_run.get_metrics()
automlvisionmetrics
# Out:
# {'classification_report': {'class_name': ['blues',
#    'classical',
#    'country',
#    'disco',
#    'hiphop',
#    'jazz',
#    'metal',
#    'pop',
#    'reggae',
#    'rock',
#    'micro avg',
#    'macro avg',
#    'weighted avg'],
#   'precision': [0.78947,
#    0.90909,
#    0.77778,
#    0.75,
#    0.77273,
#    0.85714,
#    0.94118,
#    0.85,
#    0.82353,
#    0.7,
#    0.815,
#    0.81709,
#    0.81709],
#   'recall': [0.75,
#    1.0,
#    0.7,
#    0.9,
#    0.85,
#    0.9,
#    0.8,
#    0.85,
#    0.7,
#    0.7,
#    0.815,
#    0.815,
#    0.815],
#   'f1-score': [0.76923,
#    0.95238,
#    0.73684,
#    0.81818,
#    0.80952,
#    0.87805,
#    0.86486,
#    0.85,
#    0.75676,
#    0.7,
#    0.815,
#    0.81358,
#    0.81358],
#   'support': [20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    20.0,
#    200.0,
#    200.0,
#    200.0],
#   'auc': [0.98,
#    0.9975,
#    0.95056,
#    0.96917,
#    0.9475,
#    0.97556,
#    0.99556,
#    0.98778,
#    0.96139,
#    0.93611,
#    0.97215,
#    0.97011,
#    0.97011],
#   'average_precision': [0.8902,
#    0.97289,
#    0.71724,
#    0.84762,
#    0.877,
#    0.93801,
#    0.96324,
#    0.90907,
#    0.85005,
#    0.69178,
#    0.86656,
#    0.86571,
#    0.86571]},
#  'precision_score_weighted': [0.17248,
#   0.50463,
#   0.63999,
#   0.69268,
#   0.74405,
#   0.73073,
#   0.6763,
#   0.7434,
#   0.75373,
#   0.78989,
#   0.7705,
#   0.78458,
#   0.80345,
#   0.78782,
#   0.81709],
#  'recall_score_micro': [0.205,
#   0.43,
#   0.63,
#   0.66,
#   0.67,
#   0.72,
#   0.645,
#   0.72,
#   0.73,
#   0.785,
#   0.765,
#   0.77,
#   0.795,
#   0.785,
#   0.815],
#  'f1_score_weighted': [0.1517,
#   0.39206,
#   0.6099,
#   0.65644,
#   0.67151,
#   0.72109,
#   0.64048,
#   0.72237,
#   0.72852,
#   0.78315,
#   0.76314,
#   0.76923,
#   0.7924,
#   0.78203,
#   0.81358],
#  'AUC_weighted': [0.64861,
#   0.87464,
#   0.92258,
#   0.93556,
#   0.942,
#   0.95739,
#   0.95747,
#   0.96153,
#   0.96344,
#   0.96728,
#   0.96603,
#   0.96575,
#   0.96861,
#   0.96986,
#   0.97011],
#  'precision_score_macro': [0.17248,
#   0.50463,
#   0.63999,
#   0.69268,
#   0.74405,
#   0.73073,
#   0.6763,
#   0.7434,
#   0.75373,
#   0.78989,
#   0.7705,
#   0.78458,
#   0.80345,
#   0.78782,
#   0.81709],
#  'average_precision_score_micro': [0.18052,
#   0.47165,
#   0.68545,
#   0.73643,
#   0.74437,
#   0.8151,
#   0.78248,
#   0.81735,
#   0.82755,
#   0.85224,
#   0.84864,
#   0.84679,
#   0.85897,
#   0.86349,
#   0.86656],
#  'AUC_micro': [0.62577,
#   0.85526,
#   0.92544,
#   0.93985,
#   0.94247,
#   0.96413,
#   0.95736,
#   0.96359,
#   0.96523,
#   0.97116,
#   0.96897,
#   0.96767,
#   0.97138,
#   0.97165,
#   0.97215],
#  'recall_score_weighted': [0.205,
#   0.43,
#   0.63,
#   0.66,
#   0.67,
#   0.72,
#   0.645,
#   0.72,
#   0.73,
#   0.785,
#   0.765,
#   0.77,
#   0.795,
#   0.785,
#   0.815],
#  'AUC_macro': [0.64861,
#   0.87464,
#   0.92258,
#   0.93556,
#   0.942,
#   0.95739,
#   0.95747,
#   0.96153,
#   0.96344,
#   0.96728,
#   0.96603,
#   0.96575,
#   0.96861,
#   0.96986,
#   0.97011],
#  'log_loss_train': [2.31369,
#   2.10522,
#   1.64864,
#   1.30628,
#   1.16811,
#   1.13478,
#   1.07317,
#   0.90084,
#   0.88942,
#   0.7829,
#   0.81097,
#   0.74535,
#   0.6816,
#   0.69856,
#   0.66428],
#  'accuracy': [0.205,
#   0.43,
#   0.63,
#   0.66,
#   0.67,
#   0.72,
#   0.645,
#   0.72,
#   0.73,
#   0.785,
#   0.765,
#   0.77,
#   0.795,
#   0.785,
#   0.815],
#  'precision_score_micro': [0.205,
#   0.43,
#   0.63,
#   0.66,
#   0.67,
#   0.72,
#   0.645,
#   0.72,
#   0.73,
#   0.785,
#   0.765,
#   0.77,
#   0.795,
#   0.785,
#   0.815],
#  'log_loss': [2.22003,
#   1.72589,
#   1.13984,
#   1.03165,
#   1.01626,
#   0.80283,
#   0.8724,
#   0.79559,
#   0.77416,
#   0.7038,
#   0.74138,
#   0.75826,
#   0.71581,
#   0.71086,
#   0.70181],
#  'f1_score_micro': [0.205,
#   0.43,
#   0.63,
#   0.66,
#   0.67,
#   0.72,
#   0.645,
#   0.72,
#   0.73,
#   0.785,
#   0.765,
#   0.77,
#   0.795,
#   0.785,
#   0.815],
#  'f1_score_macro': [0.1517,
#   0.39206,
#   0.6099,
#   0.65644,
#   0.67151,
#   0.72109,
#   0.64048,
#   0.72237,
#   0.72852,
#   0.78315,
#   0.76314,
#   0.76923,
#   0.7924,
#   0.78203,
#   0.81358],
#  'average_precision_score_macro': [0.23226,
#   0.56357,
#   0.68907,
#   0.73054,
#   0.75469,
#   0.80501,
#   0.78822,
#   0.81058,
#   0.82692,
#   0.83793,
#   0.83979,
#   0.84619,
#   0.85462,
#   0.86298,
#   0.86571],
#  'average_precision_score_weighted': [0.23226,
#   0.56357,
#   0.68907,
#   0.73054,
#   0.75469,
#   0.80501,
#   0.78822,
#   0.81058,
#   0.82692,
#   0.83793,
#   0.83979,
#   0.84619,
#   0.85462,
#   0.86298,
#   0.86571],
#  'recall_score_macro': [0.205,
#   0.43,
#   0.63,
#   0.66,
#   0.67,
#   0.72,
#   0.645,
#   0.72,
#   0.73,
#   0.785,
#   0.765,
#   0.77,
#   0.795,
#   0.785,
#   0.815],
#  'accuracy_train': [0.1175,
#   0.2975,
#   0.445,
#   0.53375,
#   0.59,
#   0.595,
#   0.6275,
#   0.69375,
#   0.68125,
#   0.72125,
#   0.72125,
#   0.74,
#   0.7475,
#   0.7475,
#   0.7725],
#  'automl2_vitb16r224.jpg': 'aml://artifactId/ExperimentRun/dcid.AutoML_0e854488-29d1-48b6-b704-cc925f36322f/automl2_vitb16r224.jpg_1647858726.png'}

# %% [markdown]
# ## 8. Register the optimal CV model from the AutoML run
# Once the run completes, we can register the model that was created from the best run (configuration that resulted in the best primary metric)

# %%
from azureml.core import Run
hyperdrive_run = Run(experiment=experiment, run_id=automl_image_run.id + '_HD')
hyperdrive_run
# Out:
# Run(Experiment: AutoMLImages-MusicGenreClassification,
# Id: AutoML_0e854488-29d1-48b6-b704-cc925f36322f_HD,
# Type: hyperdrive,
# Status: Completed)

# %%
# Defining tags for the custom vision model
cvmodel_tags={"Data": "Images", 
              "Context" : "Music Genre Classification",
              "Task" : "Best AutoML Images",
              "Framework" : "AzureML AutoML for Images",
              "AutoML Metric" : "Accuracy"}

# %%
# Register the best model from the AutoML Vision run in ONNX file format
best_child_run = automl_image_run.get_best_child()

model = best_child_run.register_model(model_name = 'MusicGenreONNX',
                                      model_path = 'train_artifacts/model.onnx',
                                      description = 'Music Genre Classification',
                                      tags = cvmodel_tags)

# %%
#os.mkdir('model')

# %%
# We can download the CV model ONNX
model.download(target_dir = 'model', exist_ok=True, exists_ok=None)
# Out:
# 'model/model.onnx'

# %%
# Checking the downloaded ONNX model file
filedir('model/model.onnx')
# Out:
# model/model.onnx | 2022-03-21 10:32:35 | 97.29 Mb

# %%
# Defining tags for the custom vision model
cvmodel_tags={"Data": "Images", 
              "Context" : "Music Genre Classification",
              "Task" : "Best AutoML Images",
              "Framework" : "AzureML AutoML for Images",
              "AutoML Metric" : "Accuracy"}

# %%
# Register the best model from the AutoML Vision run
best_child_run = automl_image_run.get_best_child()
model_name = best_child_run.properties['model_name']

model = best_child_run.register_model(model_name = model_name,
                                      model_path='outputs/model.pt',
                                      description='Music Genre Classification',
                                      tags=cvmodel_tags)

# %%
# We can download the CV model
model.download(target_dir='model', exist_ok=True, exists_ok=None)
# Out:
# 'model/model.pt'

# %%
# Checking the downloaded .pt model file
filedir('model/model.pt')
# Out:
# model/model.pt | 2022-03-21 10:32:48 | 195.24 Mb

# %% [markdown]
# ### Model informations from the Azure ML model repository

# %%
model
# Out:
# Model(workspace=Workspace.create(name='azuremlvision', subscription_id='70b8f39e-8863-49f7-b6ba-34a80799550c', resource_group='azuremlvision-rg'), name=AutoML0e85448824, id=AutoML0e85448824:1, version=1, tags={'Data': 'Images', 'Context': 'Music Genre Classification', 'Task': 'Best AutoML Images', 'Framework': 'AzureML AutoML for Images', 'AutoML Metric': 'Accuracy'}, properties={})

# %%
model.id
# Out:
# 'AutoML0e85448824:1'

# %%
model.name
# Out:
# 'AutoML0e85448824'

# %%
model.version
# Out:
# 1

# %%
model.tags
# Out:
# {'Data': 'Images',
#  'Context': 'Music Genre Classification',
#  'Task': 'Best AutoML Images',
#  'Framework': 'AzureML AutoML for Images',
#  'AutoML Metric': 'Accuracy'}

# %%
model.created_time
# Out:
# datetime.datetime(2022, 3, 21, 10, 32, 43, 129328, tzinfo=<isodate.tzinfo.Utc object at 0x7f603b70c8d0>)

# %% [markdown]
# ## 9. Deploy model as a web service
# Once you have your trained model, you can deploy the model on Azure. **You can deploy your trained model as a web service on Azure Container Instances ([ACI](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-container-instance)) or Azure Kubernetes Service ([AKS](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-kubernetes-service)).**<br><br> ACI is the perfect option for testing deployments, while AKS is better suited for for high-scale, production usage. <br><br>
# **In this tutorial, we will deploy the model as a web service in AKS.**
# You will need to first create an AKS compute cluster, or use an existing AKS cluster. <br>
# You can use either GPU or CPU VM SKUs for your deployment cluster

# %%
# %%time
from azureml.core.compute import ComputeTarget, AksCompute
from azureml.exceptions import ComputeTargetException

# Choose a name for your cluster
aks_name = "aks-cluster"

# Check to see if the cluster already exists
try:
    aks_target = ComputeTarget(workspace=ws, name=aks_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    # Provision AKS cluster with GPU machine
    prov_config = AksCompute.provisioning_configuration(vm_size="STANDARD_NC6", 
                                                        location="westeurope")
    # Create the cluster
    aks_target = ComputeTarget.create(workspace=ws, 
                                      name=aks_name, 
                                      provisioning_configuration=prov_config)
    aks_target.wait_for_completion(show_output=True)
# Out:
# Found existing compute target.
# CPU times: user 16.9 ms, sys: 196 µs, total: 17.1 ms
# Wall time: 120 ms

# %% [markdown]
# Next, you will need to define the inference configuration, that describes how to set up the web-service containing your model. You can use the scoring script and the environment from the training run in your inference config.
# You can then deploy the model as an AKS web service.

# %%
from azureml.core.model import InferenceConfig
from azureml.core.webservice import AksWebservice
from azureml.core.webservice import Webservice
from azureml.core.model import Model
from azureml.core.environment import Environment

endpoint_name='automl-musicgenre' # Name of the deployed model

aks_tags={"Data": "Images Sounds", 
          "Topic" : "Music Genre Classificationy", 
          "Task" : "Image Classification",
          "Framework" : "AutoML Images best model", 
          "AKS" : "True"}

aks_description="Computer vision model to detect Sound Anomaly"


best_child_run.download_file('outputs/scoring_file_v_1_0_0.py', output_file_path='model/score.py')
environment = best_child_run.get_environment()
inference_config = InferenceConfig(entry_script='model/score.py', environment=environment)

aks_config = AksWebservice.deploy_configuration(autoscale_enabled=True,                                                    
                                                cpu_cores=1,
                                                memory_gb=50,
                                                enable_app_insights=True,
                                                description=aks_description,
                                                tags=aks_tags)

# %%
# Checking the file we downloaded
filedir('model/score.py')
# Out:
# model/score.py | 2022-03-21 10:33:07 | 0.0 Mb

# %%
# Viewing the score.py file
with open(os.path.join('model/score.py'), 'r') as f:
    print(f.read())
# Out:
# # ---------------------------------------------------------
# # Copyright (c) Microsoft Corporation. All rights reserved.
# # ---------------------------------------------------------
# import os
# import tempfile
# import logging
#
# from azureml.contrib.services.aml_request import rawhttp
# from azureml.automl.core.shared import logging_utilities
# from azureml.contrib.services.aml_response import AMLResponse
# from azureml.core.model import Model
#
# from azureml.automl.dnn.vision.common.utils import _set_logging_parameters
# from azureml.automl.dnn.vision.common.model_export_utils import load_model, run_inference
# from azureml.automl.dnn.vision.common.logging_utils import get_logger
#
# from azureml.automl.dnn.vision.classification.inference.score import _score_with_model
#
# TASK_TYPE = 'image-classification'
# logger = get_logger('azureml.automl.core.scoring_script_images')
#
#
# def init():
#     global model
#
#     # Set up logging
#     _set_logging_parameters(TASK_TYPE, {})
#
#     model_path = Model.get_model_path(model_name='AutoML0e85448824')
#
#     try:
#         logger.info("Loading model from path: {}.".format(model_path))
#         model_settings = {"valid_resize_size": 256, "valid_crop_size": 224, "train_crop_size": 224}
#         model = load_model(TASK_TYPE, model_path, **model_settings)
#         logger.info("Loading successful.")
#     except Exception as e:
#         logging_utilities.log_traceback(e, logger)
#         raise
#
#
# @rawhttp
# def run(request):
#     logger.info("Request: [{0}]".format(request))
#     if request.method == 'GET':
#         response_body = str.encode(request.full_path)
#         return AMLResponse(response_body, 200)
#     elif request.method == 'POST':
#         request_body = request.get_data()
#         logger.info("Running inference.")
#         result = run_inference(model, request_body, _score_with_model)
#         logger.info("Finished inferencing.")
#         return AMLResponse(result, 200)
#     else:
#         return AMLResponse("bad request", 500)

# %% [markdown]
# ### Let's deploy the CV model into AKS

# %%
# %%time
aks_service = Model.deploy(ws,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aks_config,
                           deployment_target=aks_target,
                           name=endpoint_name,
                           overwrite=True)

aks_service.wait_for_deployment(show_output=True)

print("\nDone. Model is deployed. Ready to use!")
print("\nAKS service status=", aks_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2022-03-21 10:33:16+00:00 Creating Container Registry if not exists.
# 2022-03-21 10:33:16+00:00 Registering the environment.
# 2022-03-21 10:33:17+00:00 Use the existing image.
# 2022-03-21 10:33:19+00:00 Creating resources in AKS.
# 2022-03-21 10:33:20+00:00 Submitting deployment to compute.
# 2022-03-21 10:33:20+00:00 Checking the status of deployment automl-musicgenre..
# 2022-03-21 10:36:50+00:00 Checking the status of inference endpoint automl-musicgenre.
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
#
# Done. Model is deployed. Ready to use!
#
# AKS service status= Healthy
# CPU times: user 707 ms, sys: 147 ms, total: 853 ms
# Wall time: 3min 42s

# %% [markdown]
# > Usually it takes 2 or 3 minutes to deploy. You can see the endpoint in Azure ML Studio

# %%
#print("CV model endpoint:", aks_service.scoring_uri)
print("CV model endpoint properties:", aks_service.properties)
print("CV model endpoint tags:", aks_service.tags)

# %%
# You can have access to the logs
#print(aks_service.get_logs())

# %% [markdown]
# ## 11. Clean up ressources

# %%
#aks_service.delete()

# %%
compute_target.delete()

# %% [markdown]
# > End of this notebook. You can use the next notebook.
